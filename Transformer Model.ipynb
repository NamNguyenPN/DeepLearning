# %%
# ## Download en_core_web_lg ##
# !python -m spacy download en_core_web_lg
# !pip install pyvi

# %%
import torch, requests, copy, torchtext, pickle, spacy, html, math,time , numpy as np, pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchtext.legacy import data
from torchtext.legacy.data import Field, BucketIterator, TabularDataset
from torch.autograd import Variable
from pyvi import ViTokenizer
from nltk.corpus import wordnet
en_t = spacy.load('en_core_web_lg')
vi_t = ViTokenizer

def tokenize_en(sentence):
    return [token.text for token in en_t.tokenizer(sentence)]
def tokenize_vi(sentence):
#     return sentence.split()
    return vi_t.tokenize(sentence).split()

# %%
LOADMODEL = True ### (False) for Train model / (True) for Test pretrained model ###

EPOCH = 10
BATCHSIZE = 2500
LR = 0.001
DEVICE ="cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)

KT=5 ## if KT = 1 => GREEDYSEARCH KT > 1 BEAMSEARCH ##
MAX_LEN=200
TRANSLATE_LEN = 50


if LOADMODEL == True:
    MODELNAME = "IWSLT15-TRANSFORMER.model"
else:
    MODELNAME = "IWSLT15-TRANSFORMER.model"
# Out:
# cuda

# %% [markdown]
# ## **PREPARE DATASET** ##

# %%
## Get dataset from server and load to LIST ##
# url="https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/"
# train_en = [line for line in requests.get(url+"train.en").text.splitlines()]
# train_vi = [line for line in requests.get(url+"train.vi").text.splitlines()]
# test_en = [line for line in requests.get(url+"tst2013.en").text.splitlines()]
# test_vi = [line for line in requests.get(url+"tst2013.vi").text.splitlines()]

# Get dataset from local
f = open("iwslt15/train.en",encoding="utf8")
train_en = [line for line in f]
f.close()
f = open("iwslt15/train.vi",encoding="utf8")
train_vi = [line for line in f]
f.close()
f = open("iwslt15/tst2013.en",encoding="utf8")
test_en = [line for line in f]
f.close()
f = open("iwslt15/tst2013.vi",encoding="utf8")
test_vi = [line for line in f]
f.close()

# %%
## Convert LIST to DATAFRAME ##

def create_df(data_en,data_vi):
    raw_data = {"English":[line for line in data_en],"Vietnamese":[line for line in data_vi]}
    df = pd.DataFrame(raw_data)
    df['EN_LEN']=df['English'].str.count(" ")
    df['VI_LEN']=df['Vietnamese'].str.count(" ")
    df = df.query("VI_LEN < %s & EN_LEN < %s"%(MAX_LEN,MAX_LEN)) # Get sentence with len < 200 
    #df = df.query("EN_LEN < VI_LEN *1.5 & EN_LEN*1.5 > VI_LEN")
    return df

train = create_df(train_en,train_vi)
test = create_df(test_en,test_vi)

train.to_csv("train.csv",index=False,encoding="utf-8")
test.to_csv("test.csv",index=False,encoding="utf-8")

# %%
EN_TEXT = Field(tokenize=tokenize_en,lower=True)
VI_TEXT = Field(tokenize=tokenize_vi,init_token="<cls>",eos_token="<eos>",lower=True)

# %%
data_fields=[('English',EN_TEXT),("Vietnamese",VI_TEXT)]
train_data,test_data = TabularDataset.splits(path="./",train='train.csv',validation='test.csv', format='csv', fields = data_fields)

# %%
## CREATE VOCAB ##
EN_TEXT.build_vocab(train_data,vectors = "glove.6B.100d", min_freq=3)
VI_TEXT.build_vocab(train_data, min_freq=3)

print(f"Number tokens in English vocabulary: {len(EN_TEXT.vocab)}")
print(f"Number tokens in Vietnamese vocabulary: {len(VI_TEXT.vocab)}")
# Out:
# Number tokens in English vocabulary: 21892
# Number tokens in Vietnamese vocabulary: 15709

# %%
print(vars(test_data.examples[1]))
# Out:
# {'English': ['when', 'i', 'was', 'little', ',', 'i', 'thought', 'my', 'country', 'was', 'the', 'best', 'on', 'the', 'planet', ',', 'and', 'i', 'grew', 'up', 'singing', 'a', 'song', 'called', '&', 'quot', ';', 'nothing', 'to', 'envy', '.', '&', 'quot', ';'], 'Vietnamese': ['khi', 'tôi', 'còn', 'nhỏ', ',', 'tôi', 'nghĩ', 'rằng', 'bắctriều', 'tiên', 'là', 'đất_nước', 'tốt', 'nhất', 'trên', 'thế_giới', 'và', 'tôi', 'thường', 'hát', 'bài', '&', 'quot', ';', 'chúng_ta', 'chẳng', 'có', 'gì', 'phải', 'ghen_tị', '.', '&', 'quot', ';']}

# %% [markdown]
# ## **CREATE BATCH AND MASK** ##

# %%
## CREATE BATCH NO PADDING ##

class AutoIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d,random_shuffler):
                for p in data.batch(d,self.batch_size * 100):
                    p_batch = data.batch(sorted(p, key= self.sort_key),self.batch_size,self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b

            self.batches = pool(self.data(),self.random_shuffler)
        else:
            self.batches=[]
            for b in data.batch(self.data(),self.batch_size,self.batch_size_fn):
                self.batches.append(sorted(b,key=self.sort_key))

global max_text_in_batch, max_label_in_batch

def batch_size_fn(new, count,sofar):
    global max_text_in_batch, max_label_in_batch
    if count == 1:
        max_text_in_batch = 0
        max_label_in_batch = 0
    max_text_in_batch = max(max_text_in_batch, len(new.English))
    max_label_in_batch = max(max_label_in_batch,len(new.Vietnamese)+2)

    text_elements = count * max_text_in_batch
    label_elements = count * max_label_in_batch

    return max(text_elements,label_elements)

# %%
## CREATE MASK ##

def nopeak_mask(size):
    np_mask = np.triu(np.ones((1,size,size)),k=1).astype('uint8')
    np_mask = Variable(torch.from_numpy(np_mask)==0)
    return np_mask.to(DEVICE)

def create_masks(src,trg):
    en_mask = (src != EN_TEXT.vocab.stoi['<pad>']).unsqueeze(-2)

    if trg is not None:
        vi_mask = (trg != VI_TEXT.vocab.stoi['<pad>']).unsqueeze(-2)

        size = trg.size(1)
        np_mask = nopeak_mask(size)
        vi_mask = vi_mask & np_mask
    else:
        vi_mask = None

    return en_mask, vi_mask

# %%
train_iter = AutoIterator(train_data,batch_size=BATCHSIZE,sort_key= lambda x: (len(x.English),len(x.Vietnamese)),device=DEVICE,
                          batch_size_fn=batch_size_fn,train=True,shuffle=True)

# %%
## GET NUMBER OF BATCH ##
for c,batch in enumerate(train_iter):
    pass
TRAIN_LEN =c
print(TRAIN_LEN)
# Out:
# 1316

# %% [markdown]
# ## **EMBEDDING** ##

# %%
class Embedder(nn.Module):
    def __init__(self,vocab_size, hidden_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.embed = nn.Embedding(vocab_size,hidden_dim)

    def forward(self,x):
#         print(type(x))
#         print(x.is_cuda)
        return self.embed(x)

class PositionalEncoder(nn.Module):
    def __init__(self,hidden_dim, max_seq_len = 800, dropout =0.1):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.dropout = nn.Dropout(dropout)

        pe = torch.zeros(max_seq_len, hidden_dim)

        for pos in range(max_seq_len):
            for i in range(0, hidden_dim, 2):
                pe[pos,i] = math.sin(pos / (10000 ** ((2*i)/hidden_dim)))
                pe[pos,i+1] = math.cos(pos / (10000 **((2*(i+1))/hidden_dim)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe',pe)

    def forward(self,x):
        x = x * math.sqrt(self.hidden_dim)
        seq_len = x.size(1)
        pe = Variable(self.pe[:,:seq_len],requires_grad=False)
        
        x = x + pe
        return self.dropout(x)

# %% [markdown]
# ## **SUBLAYERS** ##

# %%
## Normalize ##
class Norm(nn.Module):
    def __init__(self, hidden_dim, eps = 1e-6):
        super().__init__()
        self.size = hidden_dim

        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))

        self.eps = eps

    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1,keepdim=True))/(x.std(dim=-1,keepdim=True)+self.eps) + self.bias
        return norm

# %%
## Attention ##
def attention(q,k,v,d_k,mask=None,dropout=None):
    scores = torch.matmul(q,k.transpose(-2,-1))/math.sqrt(d_k)
    if mask is not None:
        mask = mask.unsqueeze(1)
        scores = scores.masked_fill(mask == 0, -1e9)

    scores = F.softmax(scores,dim=-1)

    if dropout is not None:
        scores = dropout(scores)
    output = torch.matmul(scores,v)
    return output

# %%
## MultiHeadAttention ##
class MultiHeadAttention(nn.Module):
    def __init__(self,heads, hidden_dim,dropout =0.1):
        super().__init__()

        self.hidden_dim = hidden_dim
        self.d_k = hidden_dim // heads
        self.h = heads

        self.q_linear = nn.Linear(hidden_dim,hidden_dim)
        self.v_linear = nn.Linear(hidden_dim,hidden_dim)
        self.k_linear = nn.Linear(hidden_dim,hidden_dim)

        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(hidden_dim,hidden_dim)

    def forward(self, q, k, v , mask = None):
        bs = q.size(0)

        q  = self.q_linear(q).view(bs,-1,self.h ,self.d_k)
        q = q.transpose(1,2)

        v  = self.v_linear(v).view(bs,-1,self.h ,self.d_k)
        v = v.transpose(1,2)

        k  = self.k_linear(k).view(bs,-1,self.h ,self.d_k)
        k = k.transpose(1,2)

        scores = attention(q,k,v,self.d_k,mask,self.dropout)

        concat = scores.transpose(1,2).contiguous().view(bs,-1,self.hidden_dim)

        output = self.out(concat)

        return output

# %%
class FeedForward(nn.Module):
    def __init__(self,hidden_dim, hidden_dim_ff=2048,dropout =0.1):
        super().__init__()

        self.l1 = nn.Linear(hidden_dim,hidden_dim_ff)
        self.dropout = nn.Dropout(dropout)
        self.l2 = nn.Linear(hidden_dim_ff,hidden_dim)

    def forward(self,x):
        x = self.dropout(F.relu(self.l1(x)))
        x = self.l2(x)
        return x

# %% [markdown]
# ## **ENCODER LAYER AND DECODER LAYER** ##

# %%
## ENCODER LAYER ##

class EncoderLayer(nn.Module):
    def __init__(self, hidden_dim, heads, dropout =0.1):
        super().__init__()
        self.norm = Norm(hidden_dim)
        self.attn = MultiHeadAttention(heads,hidden_dim,dropout=dropout)
        self.ff = FeedForward(hidden_dim,dropout=dropout)
        self.dropout = nn.Dropout(dropout)

    def forward(self,x,mask):
        x_norm = self.norm(x)
        x = x + self.dropout(self.attn(x_norm,x_norm,x_norm,mask))
        x_norm = self.norm(x)
        x = x + self.dropout(self.ff(x_norm))

        return x

# %%
## CREATE LAYERS ##
def clone_module(module,N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, hidden_dim, N , heads, dropout):
        super().__init__()
        self.N = N
        self.embed = Embedder(vocab_size, hidden_dim)
        self.pe = PositionalEncoder(hidden_dim,dropout=dropout)
        self.layers = clone_module(EncoderLayer(hidden_dim,heads,dropout),N)
        self.norm = Norm(hidden_dim)

    def forward(self,en,mask):
        x = self.embed(en)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,mask)
        
        return self.norm(x)

# %%
## DECODER LAYER ##

class DecoderLayer(nn.Module):
    def __init__(self, hidden_dim, heads ,dropout=0.1):
        super().__init__()
        self.norm = Norm(hidden_dim)
        self.dropout= nn.Dropout(dropout)
        self.attn = MultiHeadAttention(heads,hidden_dim,dropout=dropout)
        self.ff = FeedForward(hidden_dim,dropout=dropout)

    def forward(self,x,emb_outputs,en_mask,vi_mask):
        x_norm = self.norm(x)
        x = x + self.dropout(self.attn(x_norm,x_norm,x_norm,vi_mask))
        x_norm = self.norm(x)
        x = x + self.dropout(self.attn(x_norm,emb_outputs,emb_outputs,en_mask))
        x_norm = self.norm(x)
        x = x+self.dropout(self.ff(x_norm))

        return x

# %%
class Decoder(nn.Module):
    def __init__(self,vocab_size, hidden_dim, N ,heads, dropout):
        super().__init__()
        self.N = N
        self.embed = Embedder(vocab_size, hidden_dim)
        self.pe = PositionalEncoder(hidden_dim,dropout=dropout)
        self.layers = clone_module(DecoderLayer(hidden_dim,heads,dropout),N)
        self.norm = Norm(hidden_dim)
    
    def forward(self,trg,emb_outputs,en_mask,vi_mask):
        x = self.embed(trg)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x,emb_outputs,en_mask,vi_mask)
        
        return self.norm(x)

# %% [markdown]
# ## **TRANSFORMER** ##

# %%
class Transformer(nn.Module):
    def __init__(self, en_vocab,vi_vocab, hidden_dim, N, heads ,dropout):
        super().__init__()
        self.encoder = Encoder(en_vocab,hidden_dim,N,heads,dropout)
        self.decoder = Decoder(vi_vocab,hidden_dim,N,heads,dropout)
        self.out = nn.Linear(hidden_dim,vi_vocab)

    def forward(self,en,vi,en_mask,vi_mask):
        enc_outputs = self.encoder(en,en_mask)

        dec_output = self.decoder(vi,enc_outputs,en_mask,vi_mask)

        output = self.out(dec_output)
        return output

# %%
## GET MODEL ##
def get_model(en_vocab, vi_vocab, hidden_dim,n_layers,heads,dropout,load=False):
    model = Transformer(en_vocab,vi_vocab,hidden_dim,n_layers,heads,dropout)
    if load==True:
        print("Model loaded")
        model=torch.load(MODELNAME)
    else:        
        for p in model.parameters():
            if p.dim()>1:
                nn.init.xavier_uniform_(p)
    return model.to(DEVICE)

# %% [markdown]
# ## **TRAIN MODEL AND TEST MODEL** ##

# %%
# GET LEN VOCAB #
en_vocab = len(EN_TEXT.vocab)
vi_vocab = len(VI_TEXT.vocab)

# %%
## SETUP MODEL ##

HIDDEN_DIM = 512
HEADS = 8
LAYERS = 3
DROPOUT = 0.1

model = get_model(en_vocab,vi_vocab,HIDDEN_DIM,LAYERS,HEADS,DROPOUT,load=LOADMODEL)
# Out:
# Model loaded

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)

if LOADMODEL == False:  ## RESET WEIGHT OF MODEL BEFORE TRAIN ##          
    model.apply(init_weights)

# %% [markdown]
# ## **TRAIN MODEL AND TEST MODEL** ##

# %%
###########################
## IMPROVE TEACHING RATE ##
###########################

class CosineWithRestarts(torch.optim.lr_scheduler._LRScheduler):

    def __init__(self,
                 optimizer: torch.optim.Optimizer,
                 T_max: int,
                 eta_min: float = 0.,
                 last_epoch: int = -1,
                 factor: float = 1.) -> None:

        self.T_max = T_max
        self.eta_min = eta_min
        self.factor = factor
        self._last_restart: int = 0
        self._cycle_counter: int = 0
        self._cycle_factor: float = 1.
        self._updated_cycle_len: int = T_max
        self._initialized: bool = False
        super(CosineWithRestarts, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        if not self._initialized:
            self._initialized = True
            return self.base_lrs

        step = self.last_epoch + 1
        self._cycle_counter = step - self._last_restart

        lrs = [
            (
                self.eta_min + ((lr - self.eta_min) / 2) *
                (
                    np.cos(
                        np.pi *
                        ((self._cycle_counter) % self._updated_cycle_len) /
                        self._updated_cycle_len
                    ) + 1
                )
            ) for lr in self.base_lrs
        ]

        if self._cycle_counter % self._updated_cycle_len == 0:
            self._cycle_factor *= self.factor
            self._cycle_counter = 0
            self._updated_cycle_len = int(self._cycle_factor * self.T_max)
            self._last_restart = step

        return lrs

# %%
## TRAIN MODEL ##
global TTIME,LOSS
def train_model(model):
    best_loss =99999999
    model.train()
    start = time.time()
    optimizer = optim.Adam(model.parameters(),lr=LR,betas=(0.9,0.98),eps = 1e-9)
    sched = CosineWithRestarts(optimizer, T_max=TRAIN_LEN)
    global TTIME,pred_temp,LOSS
    LOSS=[]
    for epoch in range(EPOCH):
        total_loss = 0

        for i , batch in enumerate(train_iter):
            
            ben = batch.English.transpose(0,1)
            bvi = batch.Vietnamese.transpose(0,1)
            bvi_input = bvi[:,:-1]
            en_mask,vi_mask = create_masks(ben,bvi_input)
            
            preds = model(ben,bvi_input,en_mask,vi_mask)
            pred_temp = preds
            ys = bvi[:,1:].contiguous().view(-1)
            optimizer.zero_grad()
            loss = F.cross_entropy(preds.view(-1,preds.size(-1)),ys,ignore_index=VI_TEXT.vocab.stoi['<pad>'])
            loss.backward()
            optimizer.step()
            sched.step()
            total_loss +=loss.item()
            if (i)%100 == 0:
                p = int(100*(i+1)/((TRAIN_LEN//100)*100))
                avg_loss = total_loss/100
                print(">>>Time %3d min : proc [%s%s] %3d%% : step %6d  : loss = %.5f "\
                      %((time.time()-start)//60,"".join("#"*(p//5)),"".join('_'*(20-(p//5))),p,i,avg_loss,))
        print("Epoch",epoch + 1,": loss",total_loss/TRAIN_LEN)
        LOSS.append(total_loss/TRAIN_LEN)
        torch.save(model, MODELNAME)
    TTIME=(time.time()-start)//60

# %% [markdown]
# #### **BEAM SEARCH** ####

# %%
def init_vars(src, model, SRC, TRG):
    
    init_tok = TRG.vocab.stoi['<cls>']
    src_mask = (src != SRC.vocab.stoi['<pad>']).unsqueeze(-2)
    e_output = model.encoder(src, src_mask)
    
    outputs = torch.LongTensor([[init_tok]]).to(DEVICE)
    
    trg_mask = nopeak_mask(1)
    
    out = model.out(model.decoder(outputs,e_output, src_mask, trg_mask))
    out = F.softmax(out, dim=-1)

    probs, ix = out[:, -1].data.topk(KT)
    log_scores = torch.Tensor([math.log(prob) for prob in probs.data[0]]).unsqueeze(0)
    
    outputs = torch.zeros(KT, TRANSLATE_LEN).long().to(DEVICE)

    outputs[:, 0] = init_tok
    outputs[:, 1] = ix[0]
    
    e_outputs = torch.zeros(KT, e_output.size(-2),e_output.size(-1)).to(DEVICE)

    e_outputs[:, :] = e_output[0]
    
    return outputs, e_outputs, log_scores

# %%
def k_best_outputs(outputs, out, log_scores, i, k):
    
    probs, ix = out[:, -1].data.topk(k)
    log_probs = torch.Tensor([math.log(p) for p in probs.data.view(-1)]).view(k, -1) + log_scores.transpose(0,1)
    k_probs, k_ix = log_probs.view(-1).topk(k)
    
    row = k_ix // k
    col = k_ix % k

    outputs[:, :i] = outputs[row, :i]
    outputs[:, i] = ix[row, col]

    log_scores = k_probs.unsqueeze(0)
    
    return outputs, log_scores

# %%
def beam_search(src, model, SRC, TRG):    

    outputs, e_outputs, log_scores = init_vars(src, model, SRC, TRG)
    eos_tok = TRG.vocab.stoi['<eos>']
    src_mask = (src != SRC.vocab.stoi['<pad>']).unsqueeze(-2)
    ind = None
    for i in range(2, TRANSLATE_LEN):
    
        trg_mask = nopeak_mask(i)

        out = model.out(model.decoder(outputs[:,:i],e_outputs, src_mask, trg_mask))

        out = F.softmax(out, dim=-1)
    
        outputs, log_scores = k_best_outputs(outputs, out, log_scores, i, KT)
        
        ones = (outputs==eos_tok).nonzero() # Occurrences of end symbols for all input sentences.
        sentence_lengths = torch.zeros(len(outputs), dtype=torch.long).to(DEVICE)
        for vec in ones:
            i = vec[0]
            if sentence_lengths[i]==0: # First end symbol has not been found yet
                sentence_lengths[i] = vec[1] # Position of first end symbol

        num_finished_sentences = len([s for s in sentence_lengths if s > 0])

        if num_finished_sentences == KT:
            alpha = 0.7
            div = 1/(sentence_lengths.type_as(log_scores)**alpha)
            _, ind = torch.max(log_scores * div, 1)
            ind = ind.data[0]
            break
    
    if ind is None:
        #length = (outputs[0]==eos_tok).nonzero()[0]
        length = len(outputs[0])
        return [TRG.vocab.itos[tok] for tok in outputs[0,1:length]]
    
    else:
        length = (outputs[ind]==eos_tok).nonzero()[0]
        return [TRG.vocab.itos[tok] for tok in outputs[ind][1:length]]

# %% [markdown]
# #### **TRANSLATE** ####

# %%
def get_synonym(word,en):
    syns = wordnet.synsets(word)
    for s in syns:
        for l in s.lemmas():
            if en.vocab.stoi[l.name()] != 0:
                return en.vocab.stoi[l.name()]
    return 0

# %%
## CONVERT ID TO WORD ##
def translate_sentence(sentence,model,en,vi):
    
    src_idx = [2]
    
    for token in sentence:
        if en.vocab.stoi[token] !=0:
            src_idx.append(en.vocab.stoi[token])
        else:
            src_idx.append(get_synonym(token,en))
    src_idx.append(3)
    sentence = Variable(torch.LongTensor([src_idx]).to(DEVICE))
    
    sentence = beam_search(sentence,model,en,vi)
    return sentence

# %%
## TEST MODEL ##
def test_model(model,en,vi):
    model.eval()
    refs = []
    preds = []
    with torch.no_grad():
        for i, batch in enumerate(test_data):
            if i == 0:
                continue
            ben = batch.English
            bvi = batch.Vietnamese
            pred = translate_sentence(ben,model,en,vi)
            print("EN_INPUT",ben)
            print("NMT_PRED",pred)
            print("VI_INPUT",bvi)
            refs.append([bvi])
            preds.append(pred)
    return refs,preds

# %%
# %%time
if LOADMODEL==False:    
    train_model(model)
# Out:
# Wall time: 0 ns

# %%
## TEST ##
ref,pred=test_model(model,EN_TEXT,VI_TEXT)
# Out:
# C:\Users\abc23\AppData\Roaming\Python\Python38\site-packages\torch\_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  ..\aten\src\ATen\native\BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# EN_INPUT ['when', 'i', 'was', 'little', ',', 'i', 'thought', 'my', 'country', 'was', 'the', 'best', 'on', 'the', 'planet', ',', 'and', 'i', 'grew', 'up', 'singing', 'a', 'song', 'called', '&', 'quot', ';', 'nothing', 'to', 'envy', '.', '&', 'quot', ';']
# NMT_PRED ['khi', 'tôi', 'còn', 'nhỏ', ',', 'tôi', 'nghĩ', 'đất_nước', 'tôi', 'là', 'nước', 'tốt', 'nhất', 'trên', 'hành_tinh', ',', 'và', 'tôi', 'lớn', 'lên', 'hát', '&', 'quot', ';', 'không', 'có', 'gì', 'cả', '.', '&', 'quot', ';']
# VI_INPUT ['khi', 'tôi', 'còn', 'nhỏ', ',', 'tôi', 'nghĩ', 'rằng', 'bắctriều', 'tiên', 'là', 'đất_nước', 'tốt', 'nhất', 'trên', 'thế_giới', 'và', 'tôi', 'thường', 'hát', 'bài', '&', 'quot', ';', 'chúng_ta', 'chẳng', 'có', 'gì', 'phải', 'ghen_tị', '.', '&', 'quot', ';']
# EN_INPUT ['and', 'i', 'was', 'very', 'proud', '.']
# NMT_PRED ['và', 'tôi', 'rất', 'tự_hào', '.']
# VI_INPUT ['tôi', 'đã', 'rất', 'tự_hào', 'về', 'đất_nước', 'tôi', '.']
# EN_INPUT ['in', 'school', ',', 'we', 'spent', 'a', 'lot', 'of', 'time', 'studying', 'the', 'history', 'of', 'kim', 'il', '-', 'sung', ',', 'but', 'we', 'never', 'learned', 'much', 'about', 'the', 'outside', 'world', ',', 'except', 'that', 'america', ',', 'south', 'korea', ',', 'japan', 'are', 'the', 'enemies', '.']
# NMT_PRED ['trong', 'trường_học', ',', 'chúng_tôi', 'đã', 'dành', 'rất', 'nhiều', 'thời_gian', 'nghiên_cứu', 'lịch_sử', 'của', '<unk>', ',', 'nhưng', 'chúng_tôi', 'chưa', 'bao_giờ', 'học', 'được', 'rất', 'nhiều', 'về', 'thế_giới', 'ngoài', 'hàn_quốc', ',', 'trừ', 'nhật_bản', ',', 'hàn_quốc', '.']
# VI_INPUT ['ở', 'trường', ',', 'chúng_tôi', 'dành', 'rất', 'nhiều', 'thời_gian', 'để', 'học', 'về', 'cuộc_đời', 'của', 'chủ_tịch', 'kim', 'ii', '-', 'sung', ',', 'nhưng', 'lại', 'không', 'học', 'nhiều', 'về', 'thế_giới', 'bên', 'ngoài', ',', 'ngoại_trừ', 'việc', 'hoa_kỳ', ',', 'hàn_quốc', 'và', 'nhật_bản', 'là', 'kẻ_thù', 'của', 'chúng_tôi', '.']
# EN_INPUT ['although', 'i', 'often', 'wondered', 'about', 'the', 'outside', 'world', ',', 'i', 'thought', 'i', 'would', 'spend', 'my', 'entire', 'life', 'in', 'north', 'korea', ',', 'until', 'everything', 'suddenly', 'changed', '.']
# NMT_PRED ['mặc_dù', 'tôi', 'thường', 'băn_khoăn', 'về', 'thế_giới', 'bên', 'ngoài', ',', 'tôi', 'nghĩ', 'rằng', 'tôi', 'sẽ', 'dành', 'toàn_bộ', 'cuộc_đời', 'mình', 'ở', 'bắc', 'triều_tiên', ',', 'cho', 'đến', 'khi', 'mọi', 'thứ', 'đã', 'thay_đổi', '.']
# VI_INPUT ['mặc_dù', 'tôi', 'đã', 'từng', 'tự', 'hỏi', 'không', 'biết', 'thế_giới', 'bên', 'ngoài', 'kia', 'như', 'thế_nào', ',', 'nhưng', 'tôi', 'vẫn', 'nghĩ', 'rằng', 'mình', 'sẽ', 'sống', 'cả', 'cuộc_đời', 'ở', 'bắctriều', 'tiên', ',', 'cho', 'tới', 'khi', 'tất_cả', 'mọi', 'thứ', 'đột_nhiên', 'thay_đổi', '.']
# EN_INPUT ['when', 'i', 'was', 'seven', 'years', 'old', ',', 'i', 'saw', 'my', 'first', 'public', 'execution', ',', 'but', 'i', 'thought', 'my', 'life', 'in', 'north', 'korea', 'was', 'normal', '.']
# NMT_PRED ['khi', 'tôi', 'còn', '7', 'tuổi', ',', 'tôi', 'nhìn', 'thấy', 'mình', 'lần', 'đầu_tiên', 'của', 'mình', ',', 'nhưng', 'tôi', 'nghĩ', 'rằng', 'cuộc_sống', 'của', 'tôi', 'đang', 'ở', 'bắc', 'triều_tiên', '.']
# VI_INPUT ['khi', 'tôi', 'lên', '7', ',', 'tôi', 'chứng_kiến', 'cảnh', 'người_ta', 'xử', 'bắn', 'công_khai', 'lần', 'đầu_tiên', 'trong', 'đời', ',', 'nhưng', 'tôi', 'vẫn', 'nghĩ', 'cuộc_sống', 'của', 'mình', 'ở', 'đây', 'là', 'hoàn_toàn', 'bình_thường', '.']
# EN_INPUT ['my', 'family', 'was', 'not', 'poor', ',', 'and', 'myself', ',', 'i', 'had', 'never', 'experienced', 'hunger', '.']
# NMT_PRED ['gia_đình', 'tôi', 'không', 'nghèo', ',', 'và', 'bản_thân', 'tôi', ',', 'tôi', 'chưa', 'bao_giờ', 'trải', 'qua', 'nạn', 'đói', '.']
# VI_INPUT ['gia_đình', 'của', 'tôi', 'không', 'nghèo', ',', 'và', 'bản_thân', 'tôi', 'thì', 'chưa', 'từng', 'phải', 'chịu', 'đói', '.']
# EN_INPUT ['but', 'one', 'day', ',', 'in', '1995', ',', 'my', 'mom', 'brought', 'home', 'a', 'letter', 'from', 'a', 'coworker', '&', 'apos;s', 'sister', '.']
# NMT_PRED ['nhưng', 'một', 'ngày', ',', 'vào', 'năm', '1995', ',', 'mẹ', 'tôi', 'mang', 'một', 'lá', 'thư', 'từ', 'một', 'lá', 'thư', 'đồng_nghiệp', 'đồng_nghiệp', 'đồng_nghiệp', 'của', 'tôi', '.']
# VI_INPUT ['nhưng', 'vào', 'một', 'ngày', 'của', 'năm', '1995', ',', 'mẹ', 'tôi', 'mang', 'về', 'nhà', 'một', 'lá', 'thư', 'từ', 'một', 'người', 'chị_em', 'cùng', 'chỗ', 'làm', 'với', 'mẹ', '.']
# EN_INPUT ['it', 'read', ',', '&', 'quot', ';', 'when', 'you', 'read', 'this', ',', 'all', 'five', 'family', 'members', 'will', 'not', 'exist', 'in', 'this', 'world', ',', 'because', 'we', 'haven', '&', 'apos;t', 'eaten', 'for', 'the', 'past', 'two', 'weeks', '.']
# NMT_PRED ['đọc', 'nó', ',', '&', 'quot', ';', 'khi', 'bạn', 'đọc', 'cuốn', 'sách', 'này', ',', 'các', 'thành_viên', 'gia_đình', 'sẽ', 'không', 'tồn_tại', 'trong', 'thế_giới', 'này', ',', 'bởi_vì', 'chúng_ta', 'chưa', 'từng', 'ăn', 'trong', 'hai', 'tuần', 'trước', '.']
# VI_INPUT ['trong', 'đó', 'có', 'viết', ':', 'khi', 'chị', 'đọc', 'được', 'những', 'dòng', 'này', 'thì', 'cả', 'gia_đình', '5', 'người', 'của', 'em', 'đã', 'không', 'còn', 'trên', 'cõi_đời', 'này', 'nữa', ',', 'bởi_vì', 'cả', 'nhà', 'em', 'đã', 'không', 'có', 'gì', 'để', 'ăn', 'trong', 'hai', 'tuần', '.']
# EN_INPUT ['we', 'are', 'lying', 'on', 'the', 'floor', 'together', ',', 'and', 'our', 'bodies', 'are', 'so', 'weak', 'we', 'are', 'ready', 'to', 'die', '.', '&', 'quot', ';']
# NMT_PRED ['chúng_ta', 'đang', 'nằm', 'trên', 'sàn', 'nhà', ',', 'và', 'cơ_thể', 'của', 'chúng_ta', 'quá', 'yếu', 'đến_nỗi', 'chúng_ta', 'sẵn_sàng', 'chết', '.', '&', 'quot', ';']
# VI_INPUT ['tất_cả', 'cùng', 'nằm', 'trên', 'sàn', ',', 'và', 'cơ_thể', 'chúng_tôi', 'yếu', 'đến', 'có_thể', 'cảm_thấy', 'như', 'cái', 'chết', 'đang', 'đến', 'rất', 'gần', '.']
# EN_INPUT ['i', 'was', 'so', 'shocked', '.']
# NMT_PRED ['tôi', 'rất', 'sốc', '.']
# VI_INPUT ['tôi', 'đã', 'bị', 'sốc', '.']
# EN_INPUT ['this', 'was', 'the', 'first', 'time', 'i', 'heard', 'that', 'people', 'in', 'my', 'country', 'were', 'suffering', '.']
# NMT_PRED ['đây', 'là', 'lần', 'đầu_tiên', 'tôi', 'nghe', 'thấy', 'rằng', 'những', 'người', 'trong', 'đất_nước', 'tôi', 'đang', 'chịu_đựng', 'nỗi', 'đau', '.']
# VI_INPUT ['vì', 'đó', 'là', 'lần', 'đầu_tiên', 'tôi', 'biết', 'rằng', 'đồng_bào', 'của', 'tôi', 'đang', 'phải', 'chịu_đựng', 'như_vậy', '.']
# EN_INPUT ['soon', 'after', ',', 'when', 'i', 'was', 'walking', 'past', 'a', 'train', 'station', ',', 'i', 'saw', 'something', 'terrible', 'that', 'i', 'can', '&', 'apos;t', 'erase', 'from', 'my', 'memory', '.']
# NMT_PRED ['ngay', 'sau', 'đó', ',', 'khi', 'tôi', 'đang', 'đi', 'bộ', 'qua', 'một', 'trạm', 'tàu', ',', 'tôi', 'thấy', 'một', 'cái', 'gì', 'đó', 'khủng_khiếp', 'mà', 'tôi', 'không_thể', 'xoá', 'những', 'ngọn', 'lửa', 'của', 'tôi', '.']
# VI_INPUT ['không', 'lâu', 'sau', 'đó', ',', 'khi', 'tôi', 'đi', 'qua', 'một', 'nhà_ga', ',', 'tôi', 'nhìn', 'thấy', 'một', 'cảnh_tượng', 'kinh_hoàng', 'mà', 'tôi', 'không', 'bao_giờ', 'có_thể', 'quên']
# EN_INPUT ['a', 'lifeless', 'woman', 'was', 'lying', 'on', 'the', 'ground', ',', 'while', 'an', 'emaciated', 'child', 'in', 'her', 'arms', 'just', 'stared', 'helplessly', 'at', 'his', 'mother', '&', 'apos;s', 'face', '.']
# NMT_PRED ['một', 'người', 'phụ_nữ', 'không', 'sống', 'trong', 'lòng', 'đất', 'là', 'người', 'đứng', 'trên', 'mặt_đất', ',', 'trong', 'khi', 'cô', 'nhìn', 'thấy', 'con_gái', 'mình', 'đang', 'nhìn', 'thẳng', 'vào', 'khuôn_mặt', 'của', 'mẹ', '.']
# VI_INPUT ['trên', 'nền', 'nhà_ga', 'là', 'xác_chết', 'của', 'một', 'người', 'đàn_bà', 'hai', 'tay', 'vẫn', 'đang', 'ôm', 'một', 'đứa', 'bé', 'hốc_hác', 'và', 'đứa', 'bé', 'chỉ', 'biết', 'nhìn', 'chằm_chằm', 'vào', 'khuôn_mặt', 'của', 'mẹ', 'nó', '.']
# EN_INPUT ['but', 'nobody', 'helped', 'them', ',', 'because', 'they', 'were', 'so', 'focused', 'on', 'taking', 'care', 'of', 'themselves', 'and', 'their', 'families', '.']
# NMT_PRED ['nhưng', ',', 'không', 'ai', 'giúp', 'họ', ',', 'bởi_vì', 'họ', 'tập_trung', 'vào', 'việc', 'chăm_sóc', 'bản_thân', 'họ', 'và', 'gia_đình', 'của', 'họ', '.']
# VI_INPUT ['nhưng', 'không', 'có', 'ai', 'giúp', 'họ', ',', 'bởi_vì', 'tất_cả', 'đều', 'đang', 'phải', 'lo', 'cho', 'chính', 'mình', 'và', 'cả', 'gia_đình', '.']
# EN_INPUT ['a', 'huge', 'famine', 'hit', 'north', 'korea', 'in', 'the', 'mid-1990s', '.']
# NMT_PRED ['nạn', 'đói', 'khủng_khiếp', 'đã', 'rơi', 'vào', 'bắc', 'triều_tiên', 'trong', 'những', 'năm', '1990', '.']
# VI_INPUT ['vào', 'giữa', 'những', 'năm', '90', ',', 'bắc', 'triều_tiên', 'trải', 'qua', 'một', 'nạn', 'đói', 'trầm_trọng', '.']
# EN_INPUT ['ultimately', ',', 'more', 'than', 'a', 'million', 'north', 'koreans', 'died', 'during', 'the', 'famine', ',', 'and', 'many', 'only', 'survived', 'by', 'eating', 'grass', ',', 'bugs', 'and', 'tree', 'bark', '.']
# NMT_PRED ['cuối_cùng', ',', 'hơn', 'một', 'triệu', 'người', 'bắc', 'triều_tiên', 'chết', 'đói', 'trong', 'suốt', 'những', 'nạn', 'đói', ',', 'và', 'chỉ', 'có', 'rất', 'nhiều', 'cỏ', ',', 'và', 'những', 'con', 'bọ', 'cánh_cứng', 'này', '.']
# VI_INPUT ['nó', 'khiến', 'hơn', 'một', 'triệu', 'người', 'triều_tiên', 'chết', 'trong', 'nạn', 'đói', ',', 'và', 'nhiều', 'người', 'chỉ', 'sống_sót', 'phải', 'ăn', 'cỏ', ',', 'sâu_bọ', 'và', 'vỏ', 'cây', '.']
# EN_INPUT ['power', 'outages', 'also', 'became', 'more', 'and', 'more', 'frequent', ',', 'so', 'everything', 'around', 'me', 'was', 'completely', 'dark', 'at', 'night', 'except', 'for', 'the', 'sea', 'of', 'lights', 'in', 'china', ',', 'just', 'across', 'the', 'river', 'from', 'my', 'home', '.']
# NMT_PRED ['quyền_lực', 'còn', 'lại', 'càng', 'trở_nên', 'ngày_càng', 'trở_nên', 'thường_xuyên', 'hơn', ',', 'vì_vậy', 'mọi', 'thứ', 'xung_quanh', 'tôi', 'hoàn_toàn', 'tối', 'với', 'ánh_sáng', 'ở', 'biển', ',', 'trừ', 'băng', 'qua', 'sông', 'băng', 'của', 'tôi', '.']
# VI_INPUT ['việc', 'cúp', 'điện', 'ngày_càng', 'xảy', 'ra', 'thường_xuyên', ',', 'vì_thế', 'mọi', 'thứ', 'xung_quanh', 'tôi', 'đều', 'chìm', 'vào', 'bóng_tối', 'khi', 'đêm', 'đến', 'ngoại_trừ', 'ánh_sáng', 'đèn', 'từ', 'phía', 'trung_quốc', 'chỉ', 'cách', 'nhà', 'tôi', 'một', 'con', 'sông', '.']
# EN_INPUT ['i', 'always', 'wondered', 'why', 'they', 'had', 'lights', 'but', 'we', 'didn', '&', 'apos;t', '.']
# NMT_PRED ['tôi', 'luôn', 'tự', 'hỏi', 'tại_sao', 'họ', 'có', 'đèn', 'nhưng', 'chúng_tôi', 'không', 'làm', 'thế', '.']
# VI_INPUT ['tôi', 'lúc_nào', 'cũng', 'tự', 'hỏi', 'là', 'tại_sao', 'họ', 'lại', 'có', 'điện', 'còn', 'chúng_tôi', 'thì', 'không', '.']
# EN_INPUT ['this', 'is', 'a', 'satellite', 'picture', 'showing', 'north', 'korea', 'at', 'night', 'compared', 'to', 'neighbors', '.']
# NMT_PRED ['đây', 'là', 'một', 'bức', 'ảnh', 'vệ_tinh', 'chiếu', 'sáng', 'ở', 'bắc', 'triều_tiên', 'so', 'với', 'các', 'hàng_xóm', '.']
# VI_INPUT ['đây', 'là', 'một', 'bức', 'ảnh', 'từ', 'vệ_tinh', 'chụp', 'bắc', 'triều_tiên', 'vào', 'ban_đêm', 'trong', 'tương_quan', 'với', 'các', 'nước', 'xung_quanh', '.']
# EN_INPUT ['this', 'is', 'the', 'amrok', 'river', ',', 'which', 'serves', 'as', 'a', 'part', 'of', 'the', 'border', 'between', 'north', 'korea', 'and', 'china', '.']
# NMT_PRED ['đây', 'là', 'dòng', 'sông', '<unk>', ',', 'nơi', 'mà', 'một', 'phần', 'của', 'biên_giới', 'giữa', 'bắc', 'triều_tiên', 'và', 'trung_quốc', '.']
# VI_INPUT ['đây', 'là', 'sông', 'áp_lục', 'nó', 'là', 'biên_giới', 'tự_nhiên', 'giữa', 'bắc', 'triều_tiên', 'và', 'trung_quốc', '.']
# EN_INPUT ['as', 'you', 'can', 'see', ',', 'the', 'river', 'can', 'be', 'very', 'narrow', 'at', 'certain', 'points', ',', 'allowing', 'north', 'koreans', 'to', 'secretly', 'cross', '.']
# NMT_PRED ['như', 'các', 'bạn', 'có_thể', 'thấy', ',', 'dòng', 'sông', 'này', 'có_thể', 'rất', 'hẹp', 'rất', 'hẹp', ',', 'cho', 'phép', 'những', 'điểm', 'yếu', 'ở', 'phía', 'bắc', 'triều_tiên', '.']
# VI_INPUT ['có_thể', 'thấy', 'là', 'lòng_sông', 'có', 'đoạn', 'rất', 'hẹp', 'vì_thế', 'một_số', 'người', 'bắc', 'triều_tiên', 'bí_mật', 'vượt', 'sang', 'trung_quốc', '.']
# EN_INPUT ['but', 'many', 'die', '.']
# NMT_PRED ['nhưng', ',', 'rất', 'nhiều', 'người', 'chết', '.']
# VI_INPUT ['nhưng', 'rất', 'nhiều', 'người', 'đã', 'chết', '.']
# EN_INPUT ['sometimes', ',', 'i', 'saw', 'dead', 'bodies', 'floating', 'down', 'the', 'river', '.']
# NMT_PRED ['đôi_khi', ',', 'tôi', 'nhìn', 'thấy', 'những', 'con', 'sông', 'chết', 'đi', 'xuống', 'sông', '.']
# VI_INPUT ['và', 'tôi', 'đã', 'nhìn', 'thấy', 'xác', 'họ', 'nổi', 'trên', 'sông', '.']
# EN_INPUT ['i', 'can', '&', 'apos;t', 'reveal', 'many', 'details', '&', '#', '91', ';', 'about', '&', '#', '93', ';', 'how', 'i', 'left', 'north', 'korea', ',', 'but', 'i', 'only', 'can', 'say', 'that', 'during', 'the', 'ugly', 'years', 'of', 'the', 'famine', 'i', 'was', 'sent', 'to', 'china', 'to', 'live', 'with', 'distant', 'relatives', '.']
# NMT_PRED ['tôi', 'không_thể', 'tiết_lộ', 'rất', 'nhiều', 'chi_tiết', 'về', 'việc', 'tôi', 'ở', 'bắc', 'triều_tiên', ',', 'nhưng', 'tôi', 'chỉ', 'có_thể', 'nói', 'rằng', 'trong', 'suốt', 'những', 'năm', 'nạn', 'đói', 'khủng_khiếp', 'khi', 'tôi', 'được', 'gửi', 'tới', 'họ_hàng', 'xa', 'với', 'họ_hàng', 'xa', '.']
# VI_INPUT ['tôi', 'không_thể', 'nói', 'cụ_thể', 'về', 'việc', 'mình', 'đã', 'trốn', 'khỏi', 'bắc', 'triều_tiên', 'như', 'thế_nào', 'chỉ', 'có_thể', 'nói', 'rằng', 'trong', 'những', 'năm_tháng', 'khốn_khó', 'vì', 'nạn', 'đói', 'ấy', 'tôi', 'được', 'gửi', 'sang', 'trung_quốc', 'để', 'sống', 'với', 'một', 'người', 'họ_hàng', 'xa', '.']
# EN_INPUT ['but', 'i', 'only', 'thought', 'that', 'i', 'would', 'be', 'separated', 'from', 'my', 'family', 'for', 'a', 'short', 'time', '.']
# NMT_PRED ['nhưng', ',', 'tôi', 'chỉ', 'nghĩ', 'rằng', 'tôi', 'sẽ', 'bị', 'tách', 'khỏi', 'gia_đình', 'mình', 'khỏi', 'một', 'thời_gian', 'ngắn', '.']
# VI_INPUT ['lúc', 'đó', ',', 'tôi', 'chỉ', 'nghĩ', 'rằng', 'mình', 'sẽ', 'phải', 'xa', 'gia_đình', 'một', 'thời_gian', 'ngắn', '.']
# EN_INPUT ['i', 'could', 'have', 'never', 'imagined', 'that', 'it', 'would', 'take', '14', 'years', 'to', 'live', 'together', '.']
# NMT_PRED ['tôi', 'chưa', 'bao_giờ', 'tưởng_tượng', 'được', 'rằng', 'nó', 'sẽ', 'mất', '14', 'năm', 'để', 'cùng', 'nhau', '.']
# VI_INPUT ['chứ', 'không', 'bao_giờ', 'tôi', 'có_thể', 'tưởng_tượng', 'rằng', 'tôi', 'sẽ', 'phải', 'xa', 'họ', 'những', '14', 'năm', 'ròng', '.']
# EN_INPUT ['in', 'china', ',', 'it', 'was', 'hard', 'living', 'as', 'a', 'young', 'girl', 'without', 'my', 'family', '.']
# NMT_PRED ['ở', 'trung_quốc', ',', 'nó', 'rất', 'khó', 'để', 'sống', 'như', 'một', 'cô', 'gái', 'trẻ', 'mà', 'không', 'có', 'gia_đình', 'tôi', '.']
# VI_INPUT ['ở', 'trung_quốc', ',', 'cuộc_sống', 'của', 'một', 'cô', 'bé', 'bị', 'cách_ly', 'khỏi', 'gia_đình', 'như', 'tôi', 'rất', 'khó_khăn', '.']
# EN_INPUT ['i', 'had', 'no', 'idea', 'what', 'life', 'was', 'going', 'to', 'be', 'like', 'as', 'a', 'north', 'korean', 'refugee', ',', 'but', 'i', 'soon', 'learned', 'it', '&', 'apos;s', 'not', 'only', 'extremely', 'difficult', ',', 'it', '&', 'apos;s', 'also', 'very', 'dangerous', ',', 'since', 'north', 'korean', 'refugees', 'are', 'considered', 'in', 'china', 'as', 'illegal', 'migrants', '.']
# NMT_PRED ['tôi', 'không', 'biết', 'cái', 'gì', 'sẽ', 'xảy', 'ra', 'là', 'cuộc_sống', 'giống', 'như', 'một', 'người', 'hàn_quốc', ',', 'nhưng', 'ngay', 'lúc', 'đó', 'tôi', 'mới', 'biết', 'rằng', 'nó', 'không', 'phải', 'là', 'cực_kỳ', 'khó', ',', 'bởi_vì', 'những', 'người', 'tị_nạn', 'ở', 'trung_quốc', '.']
# VI_INPUT ['tôi', 'đã', 'không_tưởng', 'được', 'những', 'gì', 'xảy', 'đến', 'với', 'cuộc_sống', 'của', 'một', 'người', 'tị_nạn', 'từ', 'bắc', 'triều_tiên', 'thì', 'sẽ', 'như', 'thế_nào', ',', 'nhưng', 'tôi', 'sớm', 'nhận', 'ra', 'rằng', 'nó', 'không_những', 'rất', 'khó_khăn', ',', 'mà', 'còn', 'vô_cùng', 'nguy_hiểm', ',', 'vì', 'những', 'người', 'tị_nạn', 'từ', 'bắc', 'triều_tiên', 'vào', 'trung_quốc', 'đều', 'bị', 'coi', 'là', 'dân', 'nhập_cư', 'trái_phép', '.']
# EN_INPUT ['so', 'i', 'was', 'living', 'in', 'constant', 'fear', 'that', 'my', 'identity', 'could', 'be', 'revealed', ',', 'and', 'i', 'would', 'be', 'repatriated', 'to', 'a', 'horrible', 'fate', 'back', 'in', 'north', 'korea', '.']
# NMT_PRED ['vậy', 'nên', ',', 'tôi', 'đang', 'sống', 'trong', 'nỗi', 'sợ', 'liên_tục', 'của', 'mình', 'rằng', 'bản_sắc', 'của', 'tôi', 'có_thể', 'được', 'tiết_lộ', ',', 'và', 'tôi', 'sẽ', 'là', 'một', 'số_phận', 'thật', 'kinh_khủng', 'khi', 'ở', 'bắc', 'triều_tiên', '.']
# VI_INPUT ['tôi', 'luôn', 'sống', 'trong', 'một', 'nỗi', 'sợ', 'thường_trực', 'rằng', 'danh_tính', 'của', 'tôi', 'sẽ', 'bị', 'phát_hiện', ',', 'và', 'tôi', 'sẽ', 'bị', 'trả', 'về', 'với', 'cuộc_sống', 'cũ', 'ở', 'bắc', 'triều_tiên', '.']
# EN_INPUT ['one', 'day', ',', 'my', 'worst', 'nightmare', 'came', 'true', ',', 'when', 'i', 'was', 'caught', 'by', 'the', 'chinese', 'police', 'and', 'brought', 'to', 'the', 'police', 'station', 'for', 'interrogation', '.']
# NMT_PRED ['một', 'ngày', 'tồi_tệ', 'nhất', ',', 'cơn', 'ác_mộng', 'tệ', 'nhất', 'của', 'tôi', 'là', 'khi', 'tôi', 'bị', 'bắt', 'cảnh_sát', 'trung_quốc', 'và', 'cảnh_sát', 'đưa', 'ra', 'khỏi', 'ga', '.']
# VI_INPUT ['một', 'ngày', ',', 'cơn', 'ác_mộng', 'đó', 'đã', 'thành', 'sự_thật', ',', 'tôi', 'đã', 'bị', 'cảnh_sát', 'trung_quốc', 'bắt', 'và', 'đưa', 'đến', 'đồn', 'cảnh_sát', 'để', 'chất_vấn', '.']
# EN_INPUT ['someone', 'had', 'accused', 'me', 'of', 'being', 'north', 'korean', ',', 'so', 'they', 'tested', 'my', 'chinese', 'language', 'abilities', 'and', 'asked', 'me', 'tons', 'of', 'questions', '.']
# NMT_PRED ['ai', 'đó', 'bị', 'buộc_tội', 'tôi', 'ở', 'phía', 'bắc', 'triều_tiên', ',', 'vì_thế', 'họ', 'kiểm_tra', 'khả_năng', 'ngôn_ngữ', 'của', 'tôi', 'và', 'hỏi', 'tôi', 'về', 'hàng', 'tấn', 'câu', 'hỏi', '.']
# VI_INPUT ['có', 'ai', 'đó', 'đã', 'báo', 'với', 'họ', 'rằng', 'tôi', 'là', 'người', 'bắc', 'triều_tiên', ',', 'vì_thế', 'họ', 'đã', 'kiểm_tra', 'khả_năng', 'tiếng', 'trung', 'của', 'tôi', 'và', 'hỏi', 'tôi', 'rất', 'nhiều', 'câu', 'hỏi', '.']
# EN_INPUT ['i', 'was', 'so', 'scared', ',', 'i', 'thought', 'my', 'heart', 'was', 'going', 'to', 'explode', '.']
# NMT_PRED ['tôi', 'đã', 'rất', 'sợ', ',', 'tôi', 'nghĩ', 'rằng', 'tim', 'của', 'mình', 'sẽ', 'nổ', 'tung', '.']
# VI_INPUT ['tôi', 'đã', 'vô_cùng', 'sợ_hãi', ',', 'và', 'có', 'cảm_giác', 'như', 'tim', 'mình', 'sắp', 'nổ', 'tung', '.']
# EN_INPUT ['if', 'anything', 'seemed', 'unnatural', ',', 'i', 'could', 'be', 'imprisoned', 'and', 'repatriated', '.']
# NMT_PRED ['nếu', 'bất_cứ', 'điều', 'gì', 'xảy', 'ra', ',', 'tôi', 'có_thể', 'bị', 'giam', 'trong', 'tù', 'và', '<unk>', '.']
# VI_INPUT ['vì', 'nếu_như', 'họ', 'thấy', 'có', 'điều', 'gì', 'không', 'tự_nhiên', ',', 'tôi', 'sẽ', 'bị', 'tống', 'vào', 'tù', 'và', 'rồi', 'bị', 'trả', 'về', 'nước', '.']
# EN_INPUT ['i', 'thought', 'my', 'life', 'was', 'over', ',', 'but', 'i', 'managed', 'to', 'control', 'all', 'the', 'emotions', 'inside', 'me', 'and', 'answer', 'the', 'questions', '.']
# NMT_PRED ['tôi', 'nghĩ', 'cuộc_sống', 'của', 'tôi', 'đã', 'vượt', 'qua', ',', 'nhưng', 'tôi', 'đã', 'cố_gắng', 'kiểm_soát', 'tất_cả', 'cảm_xúc', 'bên', 'trong', 'tôi', 'và', 'trả_lời', 'câu', 'hỏi', '.']
# VI_INPUT ['tôi', 'nghĩ', 'cuộc_đời', 'mình', 'đến', 'đây', 'là', 'chấm_dứt', ',', 'nhưng', 'tôi', 'vẫn', 'cố_gắng', 'điều_khiển', 'những', 'cảm_xúc', 'của', 'mình', 'và', 'trả_lời', 'những', 'câu', 'hỏi', 'của', 'họ', '.']
# EN_INPUT ['after', 'they', 'finished', 'questioning', 'me', ',', 'one', 'official', 'said', 'to', 'another', ',', '&', 'quot', ';', 'this', 'was', 'a', 'false', 'report', '.']
# NMT_PRED ['sau', 'đó', ',', 'họ', 'đã', 'tự', 'hỏi', 'tôi', ',', 'một', 'người', 'chính_thức', 'nói', 'với', 'tôi', ',', '&', 'quot', ';', 'đây', 'là', 'một', 'báo_cáo', 'sai', '.']
# VI_INPUT ['sau', 'khi', 'hỏi', 'xong', ',', 'một', 'trong', 'hai', 'cảnh_sát', 'nói', 'với', 'người', 'kia', ',', 'đây', 'là', 'một', 'vụ', 'chỉ_điểm', 'sai', '.']
# EN_INPUT ['she', '&', 'apos;s', 'not', 'north', 'korean', '.', '&', 'quot', ';']
# NMT_PRED ['cô', 'ấy', 'không', 'phải', 'bắc', 'triều_tiên', '.', '&', 'quot', ';']
# VI_INPUT ['nó', 'không', 'phải', 'là', 'người', 'bắc', 'triều_tiên', '.', '&', 'quot', ';']
# EN_INPUT ['and', 'they', 'let', 'me', 'go', '.', 'it', 'was', 'a', 'miracle', '.']
# NMT_PRED ['và', ',', 'chúng', 'cho', 'phép', 'tôi', 'đi', '.', 'đó', 'là', 'một_phép', 'màu', '.']
# VI_INPUT ['và', 'họ', 'thả', 'tôi', 'ra', '.', 'đó', 'quả', 'là', 'một_phép', 'màu', '.']
# EN_INPUT ['some', 'north', 'koreans', 'in', 'china', 'seek', 'asylum', 'in', 'foreign', 'embassies', ',', 'but', 'many', 'can', 'be', 'caught', 'by', 'the', 'chinese', 'police', 'and', 'repatriated', '.']
# NMT_PRED [',', 'một_số', 'người', 'hàn_quốc', 'ở', 'trung_quốc', 'để', 'tìm', 'ra', 'tiếng', 'nước_ngoài', 'ở', 'đại_sứ_quán', 'nước_ngoài', 'nhưng', 'có_thể', 'bị', 'bắt', 'bởi', 'cảnh_sát', 'trung_quốc', 'và', '<unk>', '.']
# VI_INPUT ['một_số', 'người', 'bắc', 'triều_tiên', 'ở', 'trung_quốc', 'đã', 'đến', 'những', 'đại_sứ_quán', 'của', 'nước_ngoài', 'để', 'xin', 'tị_nạn', ',', 'nhưng', 'rất', 'nhiều', 'trong', 'số', 'đó', 'đã', 'bị', 'bắt', 'bởi', 'cảnh_sát', 'trung_quốc', 'và', 'bị', 'trả', 'về', 'nước', '.']
# EN_INPUT ['these', 'girls', 'were', 'so', 'lucky', '.']
# NMT_PRED ['những', 'cô', 'gái', 'này', 'rất', 'may_mắn', '.']
# VI_INPUT ['những', 'cô', 'gái', 'này', 'đã', 'rất', 'may_mắn', '.']
# EN_INPUT ['even', 'though', 'they', 'were', 'caught', ',', 'they', 'were', 'eventually', 'released', 'after', 'heavy', 'international', 'pressure', '.']
# NMT_PRED ['ngay', 'cả', 'khi', 'họ', 'bị', 'bắt', ',', 'họ', 'cuối_cùng', 'được', 'thả', 'sau', 'khi', 'bị', 'nặng', 'nghiêm_trọng', '.']
# VI_INPUT ['vì', 'mặc_dù', 'đã', 'bị', 'bắt', ',', 'nhưng', 'cuối_cùng', 'học', 'cũng', 'được', 'thả', 'ra', 'nhờ', 'vào', 'sức_ép', 'từ', 'cộng_đồng', 'quốc_tế', '.']
# EN_INPUT ['these', 'north', 'koreans', 'were', 'not', 'so', 'lucky', '.']
# NMT_PRED ['đây', 'là', 'những', 'người', 'hàn_quốc', 'bắc', 'triều_tiên', 'cũng', 'không', 'may_mắn', '.']
# VI_INPUT ['nhưng', 'những', 'người', 'bắc', 'triều_tiên', 'này', 'thì', 'không', 'được', 'may_mắn', 'như_vậy', '.']
# EN_INPUT ['every', 'year', ',', 'countless', 'north', 'koreans', 'are', 'caught', 'in', 'china', 'and', 'repatriated', 'to', 'north', 'korea', ',', 'where', 'they', 'can', 'be', 'tortured', ',', 'imprisoned', 'or', 'publicly', 'executed', '.']
# NMT_PRED ['hàng', 'năm', ',', 'hàng', 'ngàn', 'người', 'bắc', 'triều_tiên', 'bị', 'bắt', 'ở', 'trung_quốc', 'và', '<unk>', 'tới', 'bắc', 'triều_tiên', ',', 'nơi', 'họ', 'có_thể', 'bị', 'tra_tấn', 'hoặc', 'bị', 'tra_tấn', '.']
# VI_INPUT ['hàng', 'năm', ',', 'có', 'vô_số', 'người', 'bắc', 'triều_tiên', 'bị', 'bắt', 'ở', 'trung_quốc', 'và', 'bị', 'trả', 'về', 'nước', ',', 'nơi', 'mà', 'họ', 'bị', 'tra_tấn', ',', 'bị', 'giam_cầm', 'hoặc', 'bị', 'xử_tử', 'công_khai', '.']
# EN_INPUT ['even', 'though', 'i', 'was', 'really', 'fortunate', 'to', 'get', 'out', ',', 'many', 'other', 'north', 'koreans', 'have', 'not', 'been', 'so', 'lucky', '.']
# NMT_PRED ['ngay', 'cả', 'khi', 'tôi', 'thực_sự', 'may_mắn', 'được', 'nhận', 'ra', 'khỏi', 'rất', 'nhiều', 'người', 'hàn_quốc', ',', 'rất', 'nhiều', 'người', 'phía', 'bắc', 'triều_tiên', 'cũng', 'không', 'may_mắn', '.']
# VI_INPUT ['trong', 'khi', 'tôi', 'rất', 'may_mắn', 'vì', 'đã', 'được', 'thả', 'ra', 'thì', 'rất', 'nhiều', 'đồng_bào', 'của', 'tôi', 'lại', 'không', 'được', 'như_vậy', '.']
# EN_INPUT ['it', '&', 'apos;s', 'tragic', 'that', 'north', 'koreans', 'have', 'to', 'hide', 'their', 'identities', 'and', 'struggle', 'so', 'hard', 'just', 'to', 'survive', '.']
# NMT_PRED ['đó', 'là', 'bi_kịch', 'của', 'những', 'người', 'hàn_quốc', 'đã', 'phải', 'giấu', 'những', 'danh_tính', 'của', 'họ', 'và', 'đấu_tranh', 'quá', 'khó_khăn', 'để', 'tồn_tại', '.']
# VI_INPUT ['việc', 'người', 'bắc', 'triều_tiên', 'phải', 'che', 'dấu', 'danh_tính', 'của', 'mình', 'và', 'đấu_tranh', 'để', 'tồn_tại', 'quả', 'là', 'một', 'bi_kịch', '.']
# EN_INPUT ['even', 'after', 'learning', 'a', 'new', 'language', 'and', 'getting', 'a', 'job', ',', 'their', 'whole', 'world', 'can', 'be', 'turned', 'upside', 'down', 'in', 'an', 'instant', '.']
# NMT_PRED ['ngay', 'cả', 'sau', 'khi', 'học', 'một', 'ngôn_ngữ', 'mới', 'và', 'nhận', 'được', 'một', 'công_việc', ',', 'toàn_bộ', 'thế_giới', 'của', 'họ', 'có_thể', 'biến', 'mất', 'trong', 'một', 'thời_điểm', '.']
# VI_INPUT ['kể_cả', 'khi', 'đã', 'học', 'tiếng', 'trung', 'và', 'tìm', 'được', 'một', 'công_việc', ',', 'thì', 'cuộc_sống', 'của', 'họ', 'cũng', 'có_thể', 'bị', 'đảo_lộn', 'hoàn_toàn', 'chỉ', 'trong', 'một', 'khoảng', 'khắc', '.']
# EN_INPUT ['that', '&', 'apos;s', 'why', ',', 'after', '10', 'years', 'of', 'hiding', 'my', 'identity', ',', 'i', 'decided', 'to', 'risk', 'going', 'to', 'south', 'korea', ',', 'and', 'i', 'started', 'a', 'new', 'life', 'yet', 'again', '.']
# NMT_PRED ['đó', 'là', 'lý_do', 'tại_sao', ',', 'sau', '10', 'năm', 'để', 'giấu', 'mình', ',', 'tôi', 'quyết_định', 'rủi_ro', 'về', 'hàn_quốc', ',', 'và', 'tôi', 'bắt_đầu', 'một', 'lần', 'nữa', '.']
# VI_INPUT ['đó', 'là', 'lý_do', 'tại_sao', 'sau', '10', 'năm', 'che', 'dấu', 'danh_tính', 'thật', 'tôi', 'quyết_định', 'liều_mình', 'đi', 'đến', 'hàn_quốc', ',', 'để', 'bắt_đầu', 'một', 'cuộc_sống', 'mới', 'một', 'lần', 'nữa', '.']
# EN_INPUT ['settling', 'down', 'in', 'south', 'korea', 'was', 'a', 'lot', 'more', 'challenging', 'than', 'i', 'had', 'expected', '.']
# NMT_PRED ['ổn_định', 'ở', 'hàn_quốc', 'đã', 'có', 'rất', 'nhiều', 'thách_thức', 'hơn', 'tôi', 'từng', 'nghĩ', '.']
# VI_INPUT ['việc', 'ổn_định', 'cuộc_sống', 'ở', 'đây', 'khó_khăn', 'hơn', 'nhiều', 'so', 'với', 'tôi', 'tưởng_tượng', '.']
# EN_INPUT ['english', 'was', 'so', 'important', 'in', 'south', 'korea', ',', 'so', 'i', 'had', 'to', 'start', 'learning', 'my', 'third', 'language', '.']
# NMT_PRED ['tiếng', 'anh', 'là', 'tiếng', 'anh', 'rất', 'quan_trọng', 'ở', 'hàn_quốc', ',', 'nên', 'tôi', 'phải', 'bắt_đầu', 'học', 'ngoại_ngữ', 'thứ', 'ba', '.']
# VI_INPUT ['vì', 'ở', 'hàn_quốc', ',', 'tiếng', 'anh', 'có', 'vị_trí', 'vô_cùng', 'quan_trọng', ',', 'nên', 'tôi', 'đã', 'bắt_đầu', 'học', 'tiếng', 'anh', ',', 'ngôn_ngữ', 'thứ', 'ba', 'của', 'tôi', '.']
# EN_INPUT ['also', ',', 'i', 'realized', 'there', 'was', 'a', 'wide', 'gap', 'between', 'north', 'and', 'south', '.']
# NMT_PRED ['ngoài_ra', ',', 'tôi', 'nhận', 'ra', 'có', 'một', 'khoảng_cách', 'rất', 'rộng', 'giữa', 'nam', 'và', 'nam', '.']
# VI_INPUT ['tôi', 'cũng', 'nhận', 'ra', 'một', 'khoảng_cách', 'rất', 'lớn', 'giữa', 'người', 'nam', 'và', 'bắc', 'triều_tiên', '.']
# EN_INPUT ['we', 'are', 'all', 'korean', ',', 'but', 'inside', ',', 'we', 'have', 'become', 'very', 'different', 'due', 'to', '67', 'years', 'of', 'division', '.']
# NMT_PRED ['tất_cả', 'chúng_ta', 'đều', 'là', 'người', 'hàn_quốc', ',', 'nhưng', 'chúng_ta', 'đã', 'trở_nên', 'rất', 'khác_biệt', 'với', '67', 'năm', '.']
# VI_INPUT ['chúng_tôi', 'đều', 'là', 'người', 'triều_tiên', ',', 'nhưng', 'đã', 'trở_nên', 'rất', 'khác', 'nhau', 'do', 'hậu_quả', 'của', '67', 'năm', 'bị', 'chia_cắt', '.']
# EN_INPUT ['i', 'even', 'went', 'through', 'an', 'identity', 'crisis', '.']
# NMT_PRED ['thậm_chí', ',', 'tôi', 'đã', 'trải', 'qua', 'một', 'cuộc', 'khủng_hoảng', 'bản_sắc', '.']
# VI_INPUT ['tôi', 'đã', 'trải', 'qua', 'một', 'cuộc', 'khủng_hoảng', 'về', 'nguồn_gốc', 'của', 'mình', '.']
# EN_INPUT ['am', 'i', 'south', 'korean', 'or', 'north', 'korean', '?']
# NMT_PRED ['tôi', 'là', 'hàn_quốc', 'hay', 'bắc', 'triều_tiên', '?']
# VI_INPUT ['tôi', 'là', 'người', 'nam', 'triều_tiên', 'hay', 'bắc', 'triều_tiên', '?']
# EN_INPUT ['where', 'am', 'i', 'from', '?', 'who', 'am', 'i', '?']
# NMT_PRED ['tôi', 'ở', 'đâu', '?', 'tôi', 'là', 'ai', '?', 'tôi', 'là', 'ai', '?']
# VI_INPUT ['tôi', 'đến', 'từ', 'đâu', '?', 'và', 'tôi', 'là', 'ai', '?']
# EN_INPUT ['suddenly', ',', 'there', 'was', 'no', 'country', 'i', 'could', 'proudly', 'call', 'my', 'own', '.']
# NMT_PRED ['đột_nhiên', ',', 'tôi', 'không', 'có', 'nước', 'nào', 'tự_hào', 'tôi', 'có_thể', 'gọi', 'riêng', 'mình', '.']
# VI_INPUT ['bỗng_nhiên', ',', 'tôi', 'chẳng', 'có', 'một', 'đất_nước', 'nào', 'để', 'có_thể', 'tự_hào', 'gọi', 'là', 'tổ_quốc', '.']
# EN_INPUT ['even', 'though', 'adjusting', 'to', 'life', 'in', 'south', 'korea', 'was', 'not', 'easy', ',', 'i', 'made', 'a', 'plan', '.']
# NMT_PRED ['tuy_nhiên', ',', 'mặc_dù', 'khả_năng', 'điều_chỉnh', 'cuộc_sống', 'ở', 'hàn_quốc', 'không', 'phải', 'là', 'một', 'kế_hoạch', 'đơn_giản', ',', 'tôi', 'đã', 'làm', 'một', 'kế_hoạch', '.']
# VI_INPUT ['mặc_dù', 'để', 'thích_ứng', 'với', 'cuộc_sống', 'ở', 'hàn_quốc', 'thì', 'không', 'dễ', 'chút', 'nào', 'nhưng', 'tôi', 'đã', 'lập', 'một', 'kế_hoạch', '.']
# EN_INPUT ['i', 'started', 'studying', 'for', 'the', 'university', 'entrance', 'exam', '.']
# NMT_PRED ['tôi', 'bắt_đầu', 'nghiên_cứu', 'về', 'trường', 'đại_học', '.']
# VI_INPUT ['và', 'bắt_đầu', 'học', 'để', 'chuẩn_bị', 'cho', 'kì', 'thi', 'đại_học', '.']
# EN_INPUT ['just', 'as', 'i', 'was', 'starting', 'to', 'get', 'used', 'to', 'my', 'new', 'life', ',', 'i', 'received', 'a', 'shocking', 'phone', 'call', '.']
# NMT_PRED ['như', 'tôi', 'đã', 'bắt_đầu', 'quen', 'với', 'cuộc_sống', 'mới', 'của', 'mình', ',', 'tôi', 'nhận', 'được', 'một', 'cuộc_gọi', 'khủng_khiếp', '.']
# VI_INPUT ['tuy_vậy', ',', 'ngay', 'khi', 'tôi', 'vừa_mới', 'làm_quen', 'với', 'cuộc_sống', 'ở', 'đây', ',', 'thì', 'tôi', 'được', 'báo', 'một', 'tin', 'khủng_khiếp', '.']
# EN_INPUT ['the', 'north', 'korean', 'authorities', 'intercepted', 'some', 'money', 'that', 'i', 'sent', 'to', 'my', 'family', ',', 'and', ',', 'as', 'a', 'punishment', ',', 'my', 'family', 'was', 'going', 'to', 'be', 'forcibly', 'removed', 'to', 'a', 'desolate', 'location', 'in', 'the', 'countryside', '.']
# NMT_PRED ['phía', 'bắc', 'triều_tiên', ',', 'những', 'nhà', 'quản_lý', 'tiền_bạc', 'mà', 'tôi', 'đã', 'gửi', 'cho', 'gia_đình', 'mình', ',', 'và', 'là', 'một', 'hình_phạt', ',', 'khi', 'gia_đình', 'tôi', 'sẽ', 'bị', 'phạt', 'tù', 'để', 'tránh', 'khỏi', 'vùng', 'nông_thôn', '.']
# VI_INPUT ['chính_quyền', 'bắc', 'triều_tiên', 'đã', 'phát_hiện', 'ra', 'số', 'tiền', 'mà', 'tôi', 'gửi', 'về', 'cho', 'gia_đình', ',', 'và', ',', 'để', 'trừng_phạt', ',', 'họ', 'sẽ', 'bắt', 'gia_đình', 'tôi', 'phải', 'chuyển', 'về', 'một', 'vùng', 'bị', 'cách_ly', 'ở', 'nông_thôn', '.']
# EN_INPUT ['they', 'had', 'to', 'get', 'out', 'quickly', ',', 'so', 'i', 'started', 'planning', 'how', 'to', 'help', 'them', 'escape', '.']
# NMT_PRED ['họ', 'phải', 'nhanh_chóng', 'nhận', 'ra', ',', 'vậy', 'nên', 'tôi', 'bắt_đầu', 'lập', 'kế_hoạch', 'để', 'giúp', 'họ', 'thoát', 'khỏi', '.']
# VI_INPUT ['để', 'họ', 'có_thể', 'nhanh_chóng', 'thoát', 'ra', 'khỏi', 'đó', ',', 'tôi', 'bắt_đầu', 'lập', 'kế_hoạch', 'giúp', 'gia_đình', 'mình', 'trốn', 'thoát', '.']
# EN_INPUT ['north', 'koreans', 'have', 'to', 'travel', 'incredible', 'distances', 'on', 'the', 'path', 'to', 'freedom', '.']
# NMT_PRED ['bắc', 'triều_tiên', ',', 'những', 'người', 'hàn_quốc', 'đã', 'phải', 'đi', 'xa', 'khoảng_cách', 'xa', 'với', 'con', 'đường', 'tự_do', '.']
# VI_INPUT ['người', 'bắc', 'triều_tiên', 'đã', 'phải', 'vượt', 'qua', 'những', 'khoảng_cách', 'dường_như', 'không_tưởng', 'để', 'đến', 'với', 'tự_do', '.']
# EN_INPUT ['it', '&', 'apos;s', 'almost', 'impossible', 'to', 'cross', 'the', 'border', 'between', 'north', 'korea', 'and', 'south', 'korea', ',', 'so', ',', 'ironically', ',', 'i', 'took', 'a', 'flight', 'back', 'to', 'china', 'and', 'i', 'headed', 'toward', 'the', 'north', 'korean', 'border', '.']
# NMT_PRED ['gần', 'như', 'không_thể', 'xuyên', 'biên_giới', 'giữa', 'hàn_quốc', 'và', 'hàn_quốc', ',', 'hàn_quốc', ',', 'hàn_quốc', ',', 'tôi', 'đã', 'quay', 'lại', 'chuyến', 'bay', 'về', 'phía', 'nam', 'trung_quốc', 'và', 'tôi', 'hướng', 'về', 'phía', 'bắc', 'triều_tiên', '.']
# VI_INPUT ['bời', 'vì', 'việc', 'vượt_biên', 'từ', 'bắc', 'sang', 'nam', 'triều_tiên', 'gần', 'như', 'là', 'không_thể', ',', 'vì_thế', ',', 'tôi', 'phải', 'bay', 'sang', 'trung_quốc', 'rồi', 'lại', 'đi', 'ngược', 'về', 'phía', 'biên_giới', 'bắc', 'triều_tiên', '.']
# EN_INPUT ['since', 'my', 'family', 'couldn', '&', 'apos;t', 'speak', 'chinese', ',', 'i', 'had', 'to', 'guide', 'them', ',', 'somehow', ',', 'through', 'more', 'than', '2,000', 'miles', 'in', 'china', 'and', 'then', 'into', 'southeast', 'asia', '.']
# NMT_PRED ['từ', 'gia_đình', 'tôi', 'không_thể', 'nói', 'tiếng', 'trung_quốc', ',', 'tôi', 'phải', 'hướng_dẫn', 'họ', 'theo', 'một_cách', 'nào', 'đó', ',', 'bằng', 'cách', 'nào', 'đó', ',', 'hơn', '2000', 'dặm', 'và', 'sau', 'đó', 'chuyển', 'sang', 'châu', 'á', '.']
# VI_INPUT ['bởi_vì', 'gia_đình', 'tôi', 'không', 'biết', 'tiếng', 'trung', ',', 'nên', 'tôi', 'phải', 'đi', 'cùng', 'mọi', 'người', 'qua', '2000', 'dặm', 'ở', 'trung_quốc', 'rồi', 'vào', 'đến', 'đông_nam_á']
# EN_INPUT ['the', 'journey', 'by', 'bus', 'took', 'one', 'week', ',', 'and', 'we', 'were', 'almost', 'caught', 'several', 'times', '.']
# NMT_PRED ['chuyến', 'đi', 'xe_buýt', 'cách', 'một', 'tuần', ',', 'chúng_tôi', 'mất', 'khoảng', 'một', 'tuần', ',', 'chúng_tôi', 'hầu_như', 'bị', 'bắt', 'được', 'vài', 'lần', '.']
# VI_INPUT ['cuộc', 'hành_trình', 'bằng', 'xe_buýt', 'kéo_dài', 'khoảng', '1', 'tuần', ',', 'và', 'đã', 'vài', 'lần', 'chúng_tôi', 'suýt', 'bị', 'bắt', '.']
# EN_INPUT ['one', 'time', ',', 'our', 'bus', 'was', 'stopped', 'and', 'boarded', 'by', 'a', 'chinese', 'police', 'officer', '.']
# NMT_PRED ['một', 'lần', ',', 'một', 'chiếc', 'xe_buýt', 'đã', 'dừng', 'lại', 'và', 'chạy', 'bằng', 'một', 'viên', 'cảnh_sát', 'trung_quốc', '.']
# VI_INPUT ['một', 'lần', ',', 'xe', 'của', 'chúng_tôi', 'bị', 'chặn', 'lại', 'và', 'bị', 'khám_xét', 'bởi', 'một', 'cảnh_sát', 'trung_quốc', '.']
# EN_INPUT ['he', 'took', 'everyone', '&', 'apos;s', 'i.d.', 'cards', ',', 'and', 'he', 'started', 'asking', 'them', 'questions', '.']
# NMT_PRED ['anh', 'ta', 'lấy', 'tất_cả', 'các', 'tấm', 'thẻ', 'đánh_dấu', ',', 'và', 'anh', 'ta', 'bắt_đầu', 'hỏi', 'họ', 'những', 'câu', 'hỏi', '.']
# VI_INPUT ['anh', 'ta', 'thu', 'chứng_minh_thư', 'của', 'tất_cả', 'mọi', 'người', ',', 'và', 'bắt_đầu', 'tra_hỏi', '.']
# EN_INPUT ['since', 'my', 'family', 'couldn', '&', 'apos;t', 'understand', 'chinese', ',', 'i', 'thought', 'my', 'family', 'was', 'going', 'to', 'be', 'arrested', '.']
# NMT_PRED ['từ', 'gia_đình', 'tôi', 'không_thể', 'hiểu', 'tiếng', 'trung_quốc', ',', 'tôi', 'nghĩ', 'rằng', 'gia_đình', 'tôi', 'sẽ', 'bị', 'bắt', '.']
# VI_INPUT ['bởi_vì', 'gia_đình', 'tôi', 'không', 'hiểu', 'tiếng', 'trung', ',', 'nên', 'tôi', 'đã', 'nghĩ', 'rằng', 'họ', 'sẽ', 'bị', 'bắt', '.']
# EN_INPUT ['as', 'the', 'chinese', 'officer', 'approached', 'my', 'family', ',', 'i', 'impulsively', 'stood', 'up', ',', 'and', 'i', 'told', 'him', 'that', 'these', 'are', 'deaf', 'and', 'dumb', 'people', 'that', 'i', 'was', 'chaperoning', '.']
# NMT_PRED ['là', 'một', 'sĩ_quan', 'trung_quốc', 'đến', 'gần', 'nhà', 'tôi', ',', 'tôi', 'đứng', 'lên', 'và', 'nói', 'với', 'anh', 'ta', 'rằng', 'tôi', 'bị', 'điếc', 'và', 'tôi', 'rất', 'ngu_ngốc', '.']
# VI_INPUT ['khi', 'người', 'cảnh_sát', 'trung_quốc', 'đến', 'gần', 'họ', ',', 'tôi', 'đã', 'ngay', 'lập_tức', 'đứng', 'dậy', 'và', 'nói', 'với', 'anh', 'ta', 'rằng', 'đây', 'là', 'những', 'người', 'câm', 'điếc', 'mà', 'tôi', 'đang', 'phải', 'đi', 'cùng', '.']
# EN_INPUT ['he', 'looked', 'at', 'me', 'suspiciously', ',', 'but', 'luckily', 'he', 'believed', 'me', '.']
# NMT_PRED ['anh', 'ta', 'nhìn', 'tôi', ',', 'nhưng', 'may_mắn', 'thay', ',', 'anh', 'ta', 'tin', 'tôi', '.']
# VI_INPUT ['anh', 'ta', 'nhìn', 'tôi', 'đầy', 'nghi_ngờ', ',', 'nhưng', 'thật', 'may_mắn', 'là', 'anh', 'ta', 'tin', 'lời', 'tôi', '.']
# EN_INPUT ['we', 'made', 'it', 'all', 'the', 'way', 'to', 'the', 'border', 'of', 'laos', ',', 'but', 'i', 'had', 'to', 'spend', 'almost', 'all', 'my', 'money', 'to', 'bribe', 'the', 'border', 'guards', 'in', 'laos', '.']
# NMT_PRED ['chúng_tôi', 'đã', 'làm', 'điều', 'đó', 'là', 'một_cách', 'để', 'vượt', 'qua', 'biên_giới', ',', 'nhưng', 'tôi', 'phải', 'bỏ', 'hết', 'tất_cả', 'các', 'khoản', 'hối_lộ', 'để', 'hối_lộ', 'để', 'hối_lộ', '.']
# VI_INPUT ['và', 'chúng_tôi', 'tiếp_tục', 'đi', 'cho', 'tới', 'biên_giới', 'lào', ',', 'nhung', 'tôi', 'đã', 'phải', 'sử_dụng', 'gần', 'như', 'toàn_bộ', 'số', 'tiền', 'mà', 'mình', 'có', 'để', 'hối_lộ', 'cho', 'những', 'người', 'canh_gác', 'biên_giới', 'lào', '.']
# EN_INPUT ['but', 'even', 'after', 'we', 'got', 'past', 'the', 'border', ',', 'my', 'family', 'was', 'arrested', 'and', 'jailed', 'for', 'illegal', 'border', 'crossing', '.']
# NMT_PRED ['nhưng', 'ngay', 'cả', 'sau', 'khi', 'chúng_tôi', 'rời', 'khỏi', 'biên_giới', ',', 'gia_đình', 'tôi', 'bị', 'bắt', 'và', 'bị', 'đuổi', 'khỏi', 'biên_giới', '.']
# VI_INPUT ['tuy_nhiên', ',', 'sau', 'khi', 'chúng_tôi', 'qua', 'được', 'biên_giới', ',', 'gia_đình', 'tôi', 'lại', 'bị', 'bắt', 'vào', 'tù', 'vì', 'tội', 'vượt_biên', 'trái_phép', '.']
# EN_INPUT ['after', 'i', 'paid', 'the', 'fine', 'and', 'bribe', ',', 'my', 'family', 'was', 'released', 'in', 'one', 'month', ',', 'but', 'soon', 'after', ',', 'my', 'family', 'was', 'arrested', 'and', 'jailed', 'again', 'in', 'the', 'capital', 'of', 'laos', '.']
# NMT_PRED ['sau', 'khi', 'tôi', 'trả', 'tiền', 'và', 'hối_lộ', ',', 'gia_đình', 'tôi', 'được', 'thả', 'vào', 'một', 'tháng', ',', 'nhưng', 'ngay', 'sau', 'khi', 'gia_đình', 'tôi', 'bị', 'bắt', ',', 'bị', 'bắt', '<unk>', '.']
# VI_INPUT ['sau', 'khi', 'tôi', 'nộp', 'tiền', 'phạt', 'và', 'đưa', 'hối_lộ', ',', 'gia_đình', 'tôi', 'được', 'thả', 'ra', 'trong', 'một', 'tháng', ',', 'rồi', 'lại', 'bị', 'bắt', 'lần', 'nữa', 'ở', 'thủ_đô', 'của', 'lào']
# EN_INPUT ['this', 'was', 'one', 'of', 'the', 'lowest', 'points', 'in', 'my', 'life', '.']
# NMT_PRED ['đây', 'là', 'một', 'trong', 'những', 'điểm', 'nhỏ', 'nhất', 'trong', 'đời', 'tôi', '.']
# VI_INPUT ['đó', 'là', 'thời_điểm', 'tuyệt_vọng', 'nhất', 'trong', 'cuộc_đời', 'tôi', '.']
# EN_INPUT ['i', 'did', 'everything', 'to', 'get', 'my', 'family', 'to', 'freedom', ',', 'and', 'we', 'came', 'so', 'close', ',', 'but', 'my', 'family', 'was', 'thrown', 'in', 'jail', 'just', 'a', 'short', 'distance', 'from', 'the', 'south', 'korean', 'embassy', '.']
# NMT_PRED ['tôi', 'đã', 'làm', 'tất_cả', 'mọi', 'thứ', 'để', 'gia_đình', 'tôi', ',', 'và', 'chúng_ta', 'tiến', 'gần', 'đến', 'gần', ',', 'nhưng', 'gia_đình', 'tôi', 'bị', 'ném', 'vào', 'tù', 'ở', 'một', 'khoảng_cách', 'ngắn', 'từ', 'phía', 'nam', 'của', 'đại_sứ_quán', 'hàn_quốc', '.']
# VI_INPUT ['tôi', 'đã', 'làm', 'đủ', 'mọi', 'cách', 'để', 'đưa', 'gia_đình', 'mình', 'đến', 'với', 'tự_do', ',', 'và', 'chũng', 'tôi', 'gần', 'như', 'đã', 'thành_công', 'nhưng', 'họ', 'lại', 'bị', 'bắt', 'trong', 'khi', 'chúng_tôi', 'chỉ', 'còn', 'cách', 'đại_sứ_quán', 'hàn_quốc', 'một', 'khoảng_cách', 'rất', 'ngắn', 'nữa', 'thôi', '.']
# EN_INPUT ['i', 'went', 'back', 'and', 'forth', 'between', 'the', 'immigration', 'office', 'and', 'the', 'police', 'station', ',', 'desperately', 'trying', 'to', 'get', 'my', 'family', 'out', ',', 'but', 'i', 'didn', '&', 'apos;t', 'have', 'enough', 'money', 'to', 'pay', 'a', 'bribe', 'or', 'fine', 'anymore', '.']
# NMT_PRED ['tôi', 'quay', 'lại', 'và', 'đi', 'ngược_lại', 'giữa', 'văn_phòng', 'nhập_cư', 'và', 'sở', 'cảnh_sát', ',', 'cố_gắng', 'để', 'gia_đình', ',', 'nhưng', 'tôi', 'không', 'có', 'đủ', 'tiền', 'để', 'hối_lộ', '.']
# VI_INPUT ['tôi', 'đi', 'đi', 'về', 'về', 'giữa', 'phòng', 'xuất', 'nhập_cảnh', 'và', 'đồn', 'cảnh_sát', ',', 'tuyệt_vọng', 'tìm', 'cách', 'để', 'đưa', 'gia_đình', 'mình', 'thoát', 'khỏi', 'đó', ',', 'nhưng', 'tôi', 'không', 'còn', 'đủ', 'tiền', 'để', 'hối_lộ', 'hay', 'trả', 'tiền', 'phạt', 'nữa', '.']
# EN_INPUT ['i', 'lost', 'all', 'hope', '.']
# NMT_PRED ['tôi', 'đã', 'mất', 'tất_cả', 'mọi', 'hy_vọng', '.']
# VI_INPUT ['tôi', 'hoàn_toàn', 'tuyệt_vọng', '.']
# EN_INPUT ['at', 'that', 'moment', ',', 'i', 'heard', 'one', 'man', '&', 'apos;s', 'voice', 'ask', 'me', ',', '&', 'quot', ';', 'what', '&', 'apos;s', 'wrong', '?', '&', 'quot', ';']
# NMT_PRED ['vào', 'thời_điểm', 'đó', ',', 'tôi', 'nghe', 'một', 'giọng', 'nói', 'của', 'một', 'người', 'đàn_ông', ':', '&', 'quot', ';', 'cái', 'gì', 'sai', '?', '&', 'quot', ';']
# VI_INPUT ['đúng', 'vào', 'lúc', 'đó', ',', 'có', 'một', 'người', 'đàn_ông', 'đã', 'hỏi', 'tôi', ',', '&', 'quot', ';', 'có', 'chuyện', 'gì', 'vậy', '?', '&', 'quot', ';']
# EN_INPUT ['i', 'was', 'so', 'surprised', 'that', 'a', 'total', 'stranger', 'cared', 'enough', 'to', 'ask', '.']
# NMT_PRED ['tôi', 'ngạc_nhiên', 'là', 'một', 'người', 'lạ', 'hoàn_toàn', 'quan_tâm', 'đến', 'việc', 'hỏi', '.']
# VI_INPUT ['tôi', 'vô_cùng', 'ngạc_nhiên', 'khi', 'một', 'người', 'hoàn_toàn', 'xa_lạ', 'lại', 'quan_tâm', 'tới', 'mức', 'hỏi', 'tôi', 'như_vậy', '.']
# EN_INPUT ['in', 'my', 'broken', 'english', ',', 'and', 'with', 'a', 'dictionary', ',', 'i', 'explained', 'the', 'situation', ',', 'and', 'without', 'hesitating', ',', 'the', 'man', 'went', 'to', 'the', 'atm', 'and', 'he', 'paid', 'the', 'rest', 'of', 'the', 'money', 'for', 'my', 'family', 'and', 'two', 'other', 'north', 'koreans', 'to', 'get', 'out', 'of', 'jail', '.']
# NMT_PRED ['trong', 'tiếng', 'anh', ',', 'tiếng', 'anh', ',', 'và', 'với', 'một', 'cuốn', 'từ_điển', ',', 'tôi', 'giải_thích', 'rằng', ',', 'không', 'phải', 'là', 'người', 'đàn_ông', 'lớn_tuổi', ',', 'và', 'anh', 'ta', 'đã', 'trả', 'tiền', 'cho', 'những', 'người', 'còn', 'lại', 'cho', 'cả', 'hai', 'người', 'còn', 'lại', 'tù', 'của', 'tôi', '.']
# VI_INPUT ['bằng', 'vốn', 'tiếng', 'anh', 'ít_ỏi', 'của', 'mình', 'và', 'một', 'quyển', 'từ_điển', ',', 'tôi', 'đã', 'kể', 'cho', 'cho', 'ông', 'ta', 'nghe', 'hoàn_cảnh', 'của', 'gia_đình', 'tôi', '.', 'không', 'một_chút', 'do_dự', ',', 'người', 'đàn_ông', 'đó', 'đã', 'đi', 'tới', 'máy', 'atm.', 'trả', 'tất_cả', 'số', 'tiền', 'còn', 'thiếu', 'cho', 'cả', 'gia_đình', 'tôi', 'và', 'hai', 'người', 'bắc', 'triều_tiên', 'khác', 'để', 'họ', 'được', 'ra', 'tù']
# EN_INPUT ['i', 'thanked', 'him', 'with', 'all', 'my', 'heart', ',', 'and', 'i', 'asked', 'him', ',', '&', 'quot', ';', 'why', 'are', 'you', 'helping', 'me', '?', '&', 'quot', ';']
# NMT_PRED ['tôi', 'cảm_ơn', 'anh', 'ta', 'với', 'anh', 'ấy', 'tất_cả', 'trái_tim', 'tôi', ',', 'và', 'tôi', 'hỏi', '&', 'quot', ';', 'tại_sao', 'anh', 'đang', 'giúp', 'tôi', '?', '&', 'quot', ';']
# VI_INPUT ['tôi', 'đã', 'cám_ơn', 'ông', 'ta', 'bằng', 'cả', 'trái_tim', 'mình', ',', 'và', 'tôi', 'cũng', 'hỏi', ',', '&', 'quot', ';', 'tại_sao', 'ông', 'lại', 'giúp_đỡ', 'tôi', '?', '&', 'quot', ';']
# EN_INPUT ['&', 'quot', ';', 'i', '&', 'apos;m', 'not', 'helping', 'you', ',', '&', 'quot', ';', 'he', 'said', '.']
# NMT_PRED ['&', 'quot', ';', 'tôi', 'không', 'giúp_đỡ', 'anh', ',', '&', 'quot', ';', 'anh', 'ta', 'nói', '.', '&', 'quot', ';']
# VI_INPUT ['&', 'quot', ';', 'tôi', 'không', 'giúp_đỡ', 'cô', ',', '&', 'quot', ';', 'ông', 'ta', 'trả_lời', '.']
# EN_INPUT ['&', 'quot', ';', 'i', '&', 'apos;m', 'helping', 'the', 'north', 'korean', 'people', '.', '&', 'quot', ';']
# NMT_PRED ['&', 'quot', ';', 'tôi', 'đang', 'giúp_đỡ', 'những', 'người', 'hàn_quốc', '.', '&', 'quot', ';']
# VI_INPUT ['&', 'quot', ';', '&', 'apos', ';', 'tôi', 'đang', 'giúp', 'người', 'bắc', 'triều_tiên', '.', '&', 'quot', ';']
# EN_INPUT ['i', 'realized', 'that', 'this', 'was', 'a', 'symbolic', 'moment', 'in', 'my', 'life', '.']
# NMT_PRED ['tôi', 'nhận', 'ra', 'rằng', 'đây', 'là', 'một', 'khoảnh_khắc', 'mang', 'tính', 'tượng_trưng', 'cho', 'cuộc_sống', 'của', 'tôi', '.']
# VI_INPUT ['tôi', 'nhận', 'ra', 'rằng', 'đó', 'là', 'một', 'khoảng', 'khắc', 'có', 'ý_nghĩa', 'vô_cùng', 'to_lớn', 'trong', 'cuộc_đời', 'tôi', '.']
# EN_INPUT ['the', 'kind', 'stranger', 'symbolized', 'new', 'hope', 'for', 'me', 'and', 'the', 'north', 'korean', 'people', 'when', 'we', 'needed', 'it', 'most', ',', 'and', 'he', 'showed', 'me', 'the', 'kindness', 'of', 'strangers', 'and', 'the', 'support', 'of', 'the', 'international', 'community', 'are', 'truly', 'the', 'rays', 'of', 'hope', 'we', 'north', 'korean', 'people', 'need', '.']
# NMT_PRED ['người', 'lạ', 'là', 'niềm', 'tin', 'mới', 'cho', 'tôi', 'hy_vọng', 'cho', 'tôi', 'về', 'phía', 'bắc', 'triều_tiên', 'và', 'khi', 'mà', 'hầu_hết', 'mọi', 'người', 'đều', 'muốn', 'tôi', 'và', 'những', 'người', 'lạ', 'của', 'cộng_đồng', 'quốc_tế', 'đang', 'ủng_hộ', 'những', 'tia', 'hy_vọng', 'của', 'họ', '.']
# VI_INPUT ['lòng', 'tốt', 'từ', 'người', 'đàn_ông', 'xa_lạ', 'trở_thành', 'biểu_tượng', 'hy_vọng', 'mới', 'cho', 'tôi', 'và', 'cả', 'những', 'người', 'dân', 'bắc', 'triều_tiên', 'khi', 'mà', 'chúng_tôi', 'đang', 'rất', 'cần', 'nó', ',', 'và', 'ông', 'ta', 'đã', 'cho', 'tôi', 'thấy', 'lòng', 'tốt', 'từ', 'những', 'người', 'xa_lạ', 'và', 'sự', 'hỗ_trợ', 'của', 'cộng_đồng', 'quốc_tế', 'chính', 'là', 'những', 'tia', 'hy_vọng', 'mà', 'người', 'bắc', 'triều_tiên', 'chúng_tôi', 'đang', 'tìm_kiếm', '.']
# EN_INPUT ['eventually', ',', 'after', 'our', 'long', 'journey', ',', 'my', 'family', 'and', 'i', 'were', 'reunited', 'in', 'south', 'korea', ',', 'but', 'getting', 'to', 'freedom', 'is', 'only', 'half', 'the', 'battle', '.']
# NMT_PRED ['cuối_cùng', ',', 'sau', 'chuyến', 'hành_trình', 'dài', 'của', 'chúng_tôi', ',', 'và', 'tôi', 'đang', 'ở', 'hàn_quốc', ',', 'hàn_quốc', ',', 'nhưng', 'để', 'nhận', 'được', 'sự', 'tự_do', 'là', 'một', 'nửa', 'cuộc_chiến', '.']
# VI_INPUT ['cuối_cùng', ',', 'sau', 'một', 'cuộc', 'hành_trình', 'dài', 'tôi', 'và', 'gia_đình', 'đã', 'được', 'đoàn_tụ', 'ở', 'hàn_quốc', ',', 'nhưng', 'đến', 'được', 'với', 'tự_do', 'mới', 'chỉ', 'là', 'một', 'nửa', 'của', 'cuộc', 'đấu_tranh', '.']
# EN_INPUT ['many', 'north', 'koreans', 'are', 'separated', 'from', 'their', 'families', ',', 'and', 'when', 'they', 'arrive', 'in', 'a', 'new', 'country', ',', 'they', 'start', 'with', 'little', 'or', 'no', 'money', '.']
# NMT_PRED ['nhiều', 'người', 'bắc', 'triều_tiên', 'cũng', 'đang', 'tách', 'rời', 'khỏi', 'gia_đình', 'họ', ',', 'và', 'khi', 'họ', 'đến', 'một', 'đất_nước', 'mới', ',', 'họ', 'bắt_đầu', 'với', 'số', 'tiền', '.']
# VI_INPUT ['rất', 'nhiều', 'người', 'bắc', 'triều_tiên', 'đang', 'bị', 'chia_cắt', 'với', 'gia_đình', 'của', 'họ', ',', 'và', 'khi', 'họ', 'đến', 'được', 'một', 'đất_nước', 'khác', ',', 'họ', 'phải', 'bắt_đầu_từ', 'đầu', 'với', 'rất', 'ít', 'hoặc', 'gần', 'như_không', 'có', 'tiền_bạc', '.']
# EN_INPUT ['so', 'we', 'can', 'benefit', 'from', 'the', 'international', 'community', 'for', 'education', ',', 'english', 'language', 'training', ',', 'job', 'training', ',', 'and', 'more', '.']
# NMT_PRED ['vậy', ',', 'chúng_ta', 'có_thể', 'hưởng', 'lợi', 'từ', 'cộng_đồng', 'quốc_tế', 'cho', 'giáo_dục', 'ngoại_ngữ', ',', 'đào_tạo', 'và', 'đào_tạo', 'thêm', 'nhiều', 'hơn', '.']
# VI_INPUT ['vì_thế', 'chúng_tôi', 'có_thể', 'nhận', 'sự', 'trợ_giúp', 'từ', 'cộng_đồng', 'quốc_tế', 'cho', 'giáo_dục', ',', 'đào_tạo', 'tiếng', 'anh', ',', 'dạy', 'nghề', ',', 'và', 'nhiều', 'lĩnh_vực', 'khác', '.']
# EN_INPUT ['we', 'can', 'also', 'act', 'as', 'a', 'bridge', 'between', 'the', 'people', 'inside', 'north', 'korea', 'and', 'the', 'outside', 'world', ',', 'because', 'many', 'of', 'us', 'stay', 'in', 'contact', 'with', 'family', 'members', 'still', 'inside', ',', 'and', 'we', 'send', 'information', 'and', 'money', 'that', 'is', 'helping', 'to', 'change', 'north', 'korea', 'from', 'inside', '.']
# NMT_PRED ['chúng_ta', 'cũng', 'có_thể', 'hành_động', 'như', 'một', 'cây', 'cầu', 'giữa', 'những', 'người', 'ở', 'bắc', 'triều_tiên', 'và', 'các', 'nước', 'bên', 'ngoài', ',', 'bởi_vì', 'rất', 'nhiều', 'thành_viên', 'trong', 'gia_đình', ',', 'chúng_tôi', 'vẫn', 'liên_lạc', 'với', 'các', 'thông_tin', 'ở', 'bắc', 'triều_tiên', 'và', 'giúp_đỡ', 'từ', 'bắc', 'triều_tiên', '.']
# VI_INPUT ['chúng_tôi', 'cũng', 'có_thể', 'đóng', 'vai_trò', 'như', 'cầu_nối', 'giữa', 'những', 'người', 'đang', 'ở', 'trong', 'bắc', 'triều_tiên', 'với', 'thế_giới', 'bên', 'ngoài', ',', 'bởi_vì', 'có', 'rất', 'nhiều', 'người', 'trong', 'chúng_tôi', 'đang', 'giữ', 'liên_lạc', 'với', 'những', 'thành_viên', 'gia_đình', 'khác', 'ở', 'trong', 'nước', ',', 'và', 'chúng_tôi', 'chia_sẻ', 'với', 'họ', 'thông_tin', 'và', 'tiền_bạc', 'để', 'có_thể', 'thay_đổi', 'bắc', 'triều_tiên', 'từ', 'phía', 'trong', '.']
# ...
# EN_INPUT ['after', 'another', 'two', 'hours', 'of', 'hiking', ',', 'the', 'winding', 'trail', 'abruptly', 'ended', 'at', 'a', 'clearing', ',', 'and', 'before', 'us', 'was', 'a', 'mass', 'of', 'holes', 'that', 'could', 'fit', 'into', 'the', 'size', 'of', 'a', 'football', 'field', ',', 'and', 'all', 'of', 'them', 'were', 'full', 'of', 'enslaved', 'people', 'laboring', '.']
# NMT_PRED ['sau', 'hai', 'tiếng', 'khác', ',', 'chuyến', 'leo', 'núi', 'đá', 'rơi', 'xuống', ',', 'và', 'chúng_tôi', 'đã', 'làm', 'ra', 'một', 'khối_lượng', 'lớn', 'với', 'kích_thước', 'của', 'một', 'sân', 'bóng', 'bầu_dục', ',', 'và', 'chúng', 'chứa', 'đầy', 'đá', '.']
# VI_INPUT ['sau', '2', 'giờ', 'cuốc_bộ', 'nữa', ',', 'dấu_vết', 'quanh_co', 'bất_ngờ', 'kết_thúc', 'tại', 'khu', 'đất', 'trống', ',', 'và', 'trước_mắt', 'chúng_tôi', 'là', 'một', 'vùng', 'la_liệt', 'những', 'cái', 'hố', 'rộng', 'bằng', 'cả', 'sân', 'bóng_đá', ',', 'chúng', 'chứa', 'đầy', 'những', 'nhân_công', 'nô_lệ', '.']
# EN_INPUT ['many', 'women', 'had', 'children', 'strapped', 'to', 'their', 'backs', 'while', 'they', 'were', 'panning', 'for', 'gold', ',', 'wading', 'in', 'water', 'poisoned', 'by', 'mercury', '.']
# NMT_PRED ['rất', 'nhiều', 'phụ_nữ', 'đã', 'buộc', 'con', 'mình', 'vào', 'lòng', 'đất', 'của', 'họ', ',', 'họ', 'được', 'trang_bị', 'cho', 'vàng', ',', 'dưới', 'nước', 'áo', 'thun', '<unk>', 'bị', 'nhiễm_độc', 'bởi', '<unk>', '.']
# VI_INPUT ['nhiều', 'phụ_nữ', 'địu', 'con', 'trên', 'lưng', 'trong', 'khi', 'đãi', 'vàng', ',', 'và', 'lội', 'qua', 'dòng', 'nước', 'nhiễm_độc', 'thuỷ_ngân', '.']
# EN_INPUT ['mercury', 'is', 'used', 'in', 'the', 'extraction', 'process', '.']
# NMT_PRED ['sao', 'thổ', 'được', 'dùng', 'trong', 'quá_trình', 'khai_thác', '.']
# VI_INPUT ['thuỷ_ngân', 'được', 'dùng', 'trong', 'quá_trình', 'chiết_xuất', '.']
# EN_INPUT ['these', 'miners', 'are', 'enslaved', 'in', 'a', 'mine', 'shaft', 'in', 'another', 'part', 'of', 'ghana', '.']
# NMT_PRED ['những', 'người', 'thợ', 'làm', 'nô_lệ', 'bị', 'phá_huỷ', 'trong', 'một', 'phần', 'khác', 'của', 'ghana', '.']
# VI_INPUT ['những', 'người', 'thợ', 'mỏ', 'này', 'bị', 'bắt', 'làm', 'nô_lệ', 'trong', 'hầm_mỏ', 'ở', '1', 'khu_vực', 'khác', 'của', 'ghana', '.']
# EN_INPUT ['when', 'they', 'came', 'out', 'of', 'the', 'shaft', ',', 'they', 'were', 'soaking', 'wet', 'from', 'their', 'own', 'sweat', '.']
# NMT_PRED ['khi', 'họ', 'đi', 'ra', 'khỏi', 'trục', ',', 'chúng', 'sẽ', 'toả', 'ra', 'khỏi', 'mồ_hôi', 'của', 'riêng', 'mình', '.']
# VI_INPUT ['khi', 'ra', 'khỏi', 'hầm', ',', 'người', 'họ', 'ướt_sũng', 'bởi', 'mồ_hôi', 'của', 'chính', 'mình', '.']
# EN_INPUT ['i', 'remember', 'looking', 'into', 'their', 'tired', ',', 'bloodshot', 'eyes', ',', 'for', 'many', 'of', 'them', 'had', 'been', 'underground', 'for', '72', 'hours', '.']
# NMT_PRED ['tôi', 'nhớ', ',', 'tôi', 'nhìn', 'vào', 'mắt', 'họ', 'mệt_mỏi', ',', 'với', 'rất', 'nhiều', 'người', 'trong', 'số', 'họ', 'đã', 'có', '72', 'tiếng', '.']
# VI_INPUT ['tôi', 'vẫn', 'nhớ', 'khi', 'nhìn', 'vào', 'đôi', 'mắt', 'đỏ_quạch', ',', 'mệt_mỏi', 'của', 'họ', 'vì', 'nhiều', 'người', 'đã', 'ở', 'dưới', 'lòng', 'đất', 'tới', '72', 'giờ', '.']
# EN_INPUT ['the', 'shafts', 'are', 'up', 'to', '300', 'feet', 'deep', ',', 'and', 'they', 'carry', 'out', 'heavy', 'bags', 'of', 'stone', 'that', 'later', 'will', 'be', 'transported', 'to', 'another', 'area', ',', 'where', 'the', 'stone', 'will', 'be', 'pounded', 'so', 'that', 'they', 'can', 'extract', 'the', 'gold', '.']
# NMT_PRED ['những', 'viên', 'gạch', 'cứng', 'lên', 'tới', '300', 'feet', ',', 'và', 'chúng', 'mang', 'những', 'túi', 'nhựa', 'nặng', 'từ', 'sau', 'đó', 'sẽ', 'được', 'vận_chuyển', 'đá', 'vào', 'một', 'khu_vực', 'khác', ',', 'vì_thế', 'chúng', 'có_thể', 'lấy', 'vàng', '.']
# VI_INPUT ['những', 'cái', 'hầm', 'sâu', 'tới', 'cả', 'trăm', 'mét', ',', 'họ', 'vác', 'lên', 'những', 'chiếc', 'túi', 'đá', 'nặng_trĩu', 'để', 'chuyển', 'chúng', 'tới', 'khu_vực', 'khác', ',', 'nơi', 'đá', 'được', 'nghiền', 'ra', 'để', 'đãi', 'lấy', 'vàng', '.']
# EN_INPUT ['at', 'first', 'glance', ',', 'the', 'pounding', 'site', 'seems', 'full', 'of', 'powerful', 'men', ',', 'but', 'when', 'we', 'look', 'closer', ',', 'we', 'see', 'some', 'less', 'fortunate', 'working', 'on', 'the', 'fringes', ',', 'and', 'children', 'too', '.']
# NMT_PRED ['đầu_tiên', ',', 'nhìn', 'lại', ',', 'địa_điểm', 'đầu_tiên', 'đang', 'đập', 'mạnh', ',', 'nhưng', 'khi', 'chúng_ta', 'nhìn', 'gần', 'hơn', ',', 'chúng_ta', 'nhìn', 'thấy', 'một_số', 'khác_biệt', 'hơn', ',', 'và', 'những', 'đứa', 'trẻ', 'cảm_thấy', 'rất', 'may_mắn', '.']
# VI_INPUT ['nhìn', 'qua', ',', 'công_trường', 'đập', 'đá', 'có', 'vẻ', 'đầy', 'những', 'người', 'khoẻ_mạnh', ',', 'nhưng', 'khi', 'nhìn', 'lại', 'gần', ',', 'có', 'những', 'nhiều', 'kém', 'may_mắn', 'hơn', 'làm_việc', 'trong', 'tình_trạng', 'khắc_nghiệt', ',', 'có', 'cả', 'trẻ_em', '.']
# EN_INPUT ['all', 'of', 'them', 'are', 'victim', 'to', 'injury', ',', 'illness', 'and', 'violence', '.']
# NMT_PRED ['tất_cả', 'bọn', 'họ', 'đều', 'là', 'nạn_nhân', ',', 'chấn_thương', ',', 'bạo_lực', 'và', 'bạo_lực', '.']
# VI_INPUT ['họ', 'đều', 'là', 'nạn_nhân', 'của', 'tổn_thương', ',', 'bệnh_tật', 'và', 'bạo_lực', '.']
# EN_INPUT ['in', 'fact', ',', 'it', '&', 'apos;s', 'very', 'likely', 'that', 'this', 'muscular', 'person', 'will', 'end', 'up', 'like', 'this', 'one', 'here', ',', 'racked', 'with', 'tuberculosis', 'and', 'mercury', 'poisoning', 'in', 'just', 'a', 'few', 'years', '.']
# NMT_PRED ['thực_ra', ',', 'nó', 'có', 'khả_năng', 'rất', 'giống', 'như', 'thế', 'này', 'của', 'người', 'này', 'sẽ', 'kết_thúc', 'như', 'thế', 'này', ',', 'một', 'trong', 'số', 'những', 'người', 'mắc', 'bệnh', 'lao', 'vào', 'năm', '<unk>', '.']
# VI_INPUT ['thực_tế', ',', 'nhiều', 'khả_năng', 'người', 'cơ_bắp', 'này', 'cuối_cùng', 'sẽ', 'giống', 'người', 'này', ',', 'bị', 'bệnh', 'lao', 'hành_hạ', 'và', 'nhiễm_độc', 'thuỷ_ngân', 'trong', 'vài', 'năm', 'nữa', '.']
# EN_INPUT ['this', 'is', 'manuru', '.', 'when', 'his', 'father', 'died', ',', 'his', 'uncle', 'trafficked', 'him', 'to', 'work', 'with', 'him', 'in', 'the', 'mines', '.']
# NMT_PRED ['đây', 'là', '<unk>', '.', 'khi', 'bố', 'cậu', 'qua_đời', ',', 'cậu', 'chú', 'chó', 'của', 'cậu', 'với', 'anh', 'ta', 'trong', 'các', 'mỏ', '.']
# VI_INPUT ['đây', 'là', 'manuru', '.', 'khi', 'cha', 'mất', ',', 'anh', 'ta', 'được', 'người', 'chú', 'đưa', 'đến', 'khu', 'mỏ', 'làm_việc', 'cùng', '.']
# EN_INPUT ['when', 'his', 'uncle', 'died', ',', 'manuru', 'inherited', 'his', 'uncle', '&', 'apos;s', 'debt', ',', 'which', 'further', 'forced', 'him', 'into', 'being', 'enslaved', 'in', 'the', 'mines', '.']
# NMT_PRED ['khi', 'chú', 'cậu', 'ta', 'qua_đời', ',', 'chú', 'chó', 'của', 'ông', 'ấy', 'là', 'món', 'nợ', 'của', 'ông', 'ta', ',', 'buộc', 'phải', 'làm', 'nô_lệ', 'bị', 'bắt', '.']
# VI_INPUT ['khi', 'người', 'chú', 'mất', ',', 'manuru', 'kế_thừa', 'món', 'nợ', 'của', 'chú', ',', 'và', 'bị', 'buộc', 'làm', 'nô_lệ', 'trong', 'khu', 'mỏ', 'này', 'lâu', 'hơn', 'nữa', '.']
# EN_INPUT ['when', 'i', 'met', 'him', ',', 'he', 'had', 'been', 'working', 'in', 'the', 'mines', 'for', '14', 'years', ',', 'and', 'the', 'leg', 'injury', 'that', 'you', 'see', 'here', 'is', 'actually', 'from', 'a', 'mining', 'accident', ',', 'one', 'so', 'severe', 'doctors', 'say', 'his', 'leg', 'should', 'be', 'amputated', '.']
# NMT_PRED ['khi', 'tôi', 'gặp', 'ông', 'ấy', ',', 'anh', 'ta', 'đã', 'làm_việc', 'trong', 'những', 'mỏ', 'của', '14', 'năm', ',', 'và', 'bạn', 'thấy', 'chấn_thương', 'chân', 'ở', 'đây', 'là', 'một', 'tai_nạn', 'gây', 'ra', 'tai_nạn', 'do', 'vậy', 'nên', 'bác_sĩ', 'phải', 'nói', '.']
# VI_INPUT ['khi', 'tôi', 'gặp', ',', 'anh', 'ta', 'đã', 'làm_việc', '14', 'năm', 'ở', 'khu', 'mỏ', ',', 'và', 'vết_thương', 'ở', 'chân', 'mà', 'bạn', 'thấy', 'đây', 'là', 'từ', '1', 'tai_nạn', 'ở', 'mỏ', ',', 'một', 'chân', 'bị_thương', 'nặng', 'đến_nỗi', 'bác_sĩ', 'nói', 'phải', 'cưa', 'đi', '.']
# EN_INPUT ['on', 'top', 'of', 'that', ',', 'manuru', 'has', 'tuberculosis', ',', 'yet', 'he', '&', 'apos;s', 'still', 'forced', 'to', 'work', 'day', 'in', 'and', 'day', 'out', 'in', 'that', 'mine', 'shaft', '.']
# NMT_PRED ['trên', 'đỉnh', 'núi', 'cao', 'nhất', ',', 'vẫn', 'bị', 'bệnh', 'lao', ',', 'nhưng', 'anh', 'ta', 'vẫn', 'bị', 'buộc', 'phải', 'làm_việc', 'trong', 'ngày', 'đó', '.']
# VI_INPUT ['trên_hết', ',', 'manuru', 'bị', 'bệnh', 'lao', ',', 'nhưng', 'vẫn', 'bị', 'bắt', 'làm_việc', 'ngày', 'qua_ngày', 'tại', 'hầm_mỏ', 'đó', '.']
# EN_INPUT ['even', 'still', ',', 'he', 'has', 'a', 'dream', 'that', 'he', 'will', 'become', 'free', 'and', 'become', 'educated', 'with', 'the', 'help', 'of', 'local', 'activists', 'like', 'free', 'the', 'slaves', ',', 'and', 'it', '&', 'apos;s', 'this', 'sort', 'of', 'determination', ',', 'in', 'the', 'face', 'of', 'unimaginable', 'odds', ',', 'that', 'fills', 'me', 'with', 'complete', 'awe', '.']
# NMT_PRED ['ngay', 'cả', ',', 'ông', 'vẫn', 'có', 'một', 'giấc', 'mơ', 'rằng', 'ông', 'sẽ', 'trở_thành', 'những', 'nhà', 'hoạt_động', 'tự_do', 'và', 'giúp_đỡ', 'những', 'người', 'hoạt_động', 'như', 'nô_lệ', 'địa_phương', ',', 'và', 'đó', 'là', 'sự', 'quyết_tâm', 'của', 'sự', 'quyết_tâm', ',', 'khiến', 'tôi', 'kinh_ngạc', '.']
# VI_INPUT ['dù_vậy', ',', 'anh', 'ta', 'vẫn', 'mơ_ước', 'được', 'tự_do', 'được', 'đi', 'học', 'với', 'sự', 'giúp_đỡ', 'của', 'những', 'nhà', 'hoạt_động', 'địa_phương', 'như', 'tổ_chức', 'giải_phóng', 'nô_lệ', ',', 'và', 'quyết_tâm', 'như', 'thế', 'này', ',', 'hiện', 'lên', 'trên', 'khuôn_mặt', 'của', 'những', 'người', 'lạ_thường', ',', 'khiến', 'tôi', 'ngập_tràn', 'sự', 'nể', 'phục', '.']
# EN_INPUT ['i', 'want', 'to', 'shine', 'a', 'light', 'on', 'slavery', '.']
# NMT_PRED ['tôi', 'muốn', 'chiếu', 'sáng', 'một', 'chế_độ', 'nô_lệ', '.']
# VI_INPUT ['tôi', 'muốn', 'đưa', 'nô_lệ', 'ra', 'ánh_sáng', '.']
# EN_INPUT ['when', 'i', 'was', 'working', 'in', 'the', 'field', ',', 'i', 'brought', 'lots', 'of', 'candles', 'with', 'me', ',', 'and', 'with', 'the', 'help', 'of', 'my', 'interpreter', ',', 'i', 'imparted', 'to', 'the', 'people', 'i', 'was', 'photographing', 'that', 'i', 'wanted', 'to', 'illuminate', 'their', 'stories', 'and', 'their', 'plight', ',', 'so', 'when', 'it', 'was', 'safe', 'for', 'them', ',', 'and', 'safe', 'for', 'me', ',', 'i', 'made', 'these', 'images', '.']
# NMT_PRED ['khi', 'tôi', 'đang', 'làm_việc', 'trong', 'lĩnh_vực', ',', 'tôi', 'mang', 'nhiều', 'ngọn', 'nến', 'lên', ',', 'với', 'tôi', ',', 'với', 'sự', 'giúp_đỡ', 'của', 'tôi', ',', 'tôi', 'muốn', 'để', 'chụp', 'hình', 'của', 'họ', ',', 'và', 'tôi', 'muốn', 'cho', 'họ', 'một', 'tình_huống', 'an_toàn', 'để', 'làm', 'cho', 'tôi', 'an_toàn', '.', '<eos>', '.', '<eos>', ',']
# VI_INPUT ['khi', 'làm_việc', 'trong', 'lãnh_vực', 'này', ',', 'tôi', 'mang', 'theo', 'rất', 'nhiều', 'nến', ',', 'với', 'sự', 'giúp_đỡ', 'của', 'người', 'phiên_dịch', ',', 'tôi', 'truyền_đạt', 'với', 'những', 'người', 'mà', 'mình', 'chụp', 'hình', 'rằng', 'tôi', 'muốn', 'soi', 'sáng', 'câu_chuyện', 'và', 'hoàn_cảnh', 'của', 'họ', ',', 'rồi', 'khi', 'họ', 'và', 'tôi', 'được', 'an_toàn', 'tôi', 'chụp', 'những', 'tấm', 'hình', 'này', '.']
# EN_INPUT ['they', 'knew', 'their', 'image', 'would', 'be', 'seen', 'by', 'you', 'out', 'in', 'the', 'world', '.']
# NMT_PRED ['chúng', 'biết', 'hình_ảnh', 'của', 'chúng', 'sẽ', 'được', 'nhìn', 'thấy', 'bởi', 'các', 'bạn', 'đã', 'thấy', 'trên', 'thế_giới', '.']
# VI_INPUT ['họ', 'biết', 'hình', 'của', 'họ', 'sẽ', 'được', 'xem', 'bởi', 'những', 'người', 'ở', 'ngoài', 'kia', ',', 'như', 'bạn']
# EN_INPUT ['i', 'wanted', 'them', 'to', 'know', 'that', 'we', 'will', 'be', 'bearing', 'witness', 'to', 'them', ',', 'and', 'that', 'we', 'will', 'do', 'whatever', 'we', 'can', 'to', 'help', 'make', 'a', 'difference', 'in', 'their', 'lives', '.']
# NMT_PRED ['tôi', 'muốn', 'họ', 'biết', 'rằng', 'chúng_ta', 'sẽ', 'phải', 'đối_mặt', 'với', 'họ', ',', 'và', 'chúng_ta', 'sẽ', 'làm', 'bất_cứ', 'điều', 'gì', 'chúng_ta', 'có_thể', 'giúp_đỡ', 'để', 'tạo', 'ra', 'sự', 'khác_biệt', 'trong', 'cuộc_sống', 'của', 'họ', '.']
# VI_INPUT ['tôi', 'muốn', 'họ', 'biết', 'rằng', 'chúng_ta', 'sẽ', 'làm_chứng', 'cho', 'họ', ',', 'và', 'ta', 'sẽ', 'làm', 'bất_cứ', 'gì', 'có_thể', 'để', 'giúp', 'họ', 'thay_đổi', 'cuộc_đời', '.']
# EN_INPUT ['i', 'truly', 'believe', ',', 'if', 'we', 'can', 'see', 'one', 'another', 'as', 'fellow', 'human', 'beings', ',', 'then', 'it', 'becomes', 'very', 'difficult', 'to', 'tolerate', 'atrocities', 'like', 'slavery', '.']
# NMT_PRED ['tôi', 'thực_sự', 'tin', 'rằng', ',', 'nếu', 'chúng_ta', 'có_thể', 'nhìn', 'thấy', 'một', 'người', 'khác', 'như', 'một', 'con_người', ',', 'thì', 'nó', 'sẽ', 'rất', 'khó', 'để', 'đánh_bại', 'nạn', 'nô_lệ', '.']
# VI_INPUT ['tôi', 'thực_sự', 'tin', ',', 'nếu', 'ta', 'coi', 'người', 'khác', 'như', 'những', 'người', 'đồng_loại', ',', 'thì', 'sẽ', 'rất', 'khó', 'để', 'khoan_hồng', 'những', 'tội_ác', 'như_nạn', 'nô_lệ', '.']
# EN_INPUT ['these', 'images', 'are', 'not', 'of', 'issues', '.', 'they', 'are', 'of', 'people', ',', 'real', 'people', ',', 'like', 'you', 'and', 'me', ',', 'all', 'deserving', 'of', 'the', 'same', 'rights', ',', 'dignity', 'and', 'respect', 'in', 'their', 'lives', '.']
# NMT_PRED ['những', 'bức', 'ảnh', 'này', 'không', 'phải', 'là', 'vấn_đề', '.', 'chúng', 'là', 'những', 'người', 'thực_sự', ',', 'như', 'tôi', ',', 'và', 'tất_cả', 'những', 'người', 'xứng_đáng', 'có', 'quyền', 'bình_đẳng', ',', 'và', 'sự', 'tôn_trọng', 'của', 'họ', '.']
# VI_INPUT ['những', 'tấm', 'hình', 'không', 'phải', 'là', 'về', 'bản_thân', 'vấnđề', '.', 'chúng', 'là', 'về', 'con_người', ',', 'người', 'thật', ',', 'như', 'bạn', 'và', 'tôi', ',', 'tất_cả', 'đều', 'xứng_đáng', 'hưởng', 'quyền', 'bằng', 'nhau', ',', 'danh_dự', 'và', 'tôn_trọng', 'như', 'nhau', 'trong', 'đời', '.']
# EN_INPUT ['there', 'is', 'not', 'a', 'day', 'that', 'goes', 'by', 'that', 'i', 'don', '&', 'apos;t', 'think', 'of', 'these', 'many', 'beautiful', ',', 'mistreated', 'people', 'i', '&', 'apos;ve', 'had', 'the', 'tremendous', 'honor', 'of', 'meeting', '.']
# NMT_PRED ['không', 'có', 'một', 'ngày', 'trôi', 'qua', 'tôi', 'nghĩ', 'rằng', 'tôi', 'không', 'nghĩ', 'đến', 'rất', 'nhiều', 'người', 'lạm_dụng', ',', 'tôi', 'đã', 'rất', 'vinh_dự', 'được', 'gặp', '.']
# VI_INPUT ['không', 'có', 'ngày', 'nào', 'mà', 'tôi', 'không', 'nghĩ', 'về', 'những', 'người', 'tuyệt_vời', 'bị', 'vùi_dập', 'này', '.', 'tôi', 'có', 'vinh_dự', 'to_lớn', 'được', 'gặp_gỡ', 'họ', '.']
# EN_INPUT ['i', 'hope', 'that', 'these', 'images', 'awaken', 'a', 'force', 'in', 'those', 'who', 'view', 'them', ',', 'people', 'like', 'you', ',', 'and', 'i', 'hope', 'that', 'force', 'will', 'ignite', 'a', 'fire', ',', 'and', 'that', 'fire', 'will', 'shine', 'a', 'light', 'on', 'slavery', ',', 'for', 'without', 'that', 'light', ',', 'the', 'beast', 'of', 'bondage', 'can', 'continue', 'to', 'live', 'in', 'the', 'shadows', '.']
# NMT_PRED ['tôi', 'hy_vọng', 'rằng', 'những', 'bức', 'ảnh', 'này', 'sẽ', 'gợi', 'lên', 'một', 'lực', 'trong', 'họ', ',', 'những', 'người', 'như', 'tôi', 'hy_vọng', ',', 'và', 'tôi', 'hy_vọng', 'rằng', 'một', 'lực', 'đẩy', 'lửa', 'sẽ', 'sáng', 'lên', 'chế_độ', 'nô_lệ', ',', 'mà', 'không', 'có', 'chế_độ', 'nô_lệ', 'để', 'nuôi', 'sống', 'trong', 'bóng_tối', '.', '<eos>', '.', '<eos>']
# VI_INPUT ['tôi', 'hi_vọng', 'những', 'tấm', 'hình', 'sẽ', 'đánh_thức', 'một', 'nguồn', 'sức_mạnh', 'trong', 'người', 'xem', ',', 'những', 'người', 'như', 'bạn', ',', 'và', 'hi_vọng', 'sức_mạnh', 'đó', 'sẽ', 'châm', 'ngọn', 'lửa', ',', 'ngọn', 'lửa', 'đó', 'sẽ', 'chiếu', 'rọi', 'vào', 'nạn', 'nô_lệ', ',', 'vì', 'không', 'có', 'ánh_sáng', 'đó', ',', 'con', 'quái_vật', 'của', 'ngục_tù', 'sẽ', 'có_thể', 'tiếp_tục', 'sống', 'trong', 'bóng_tối', '.']
# EN_INPUT ['thank', 'you', 'very', 'much', '.']
# NMT_PRED ['cảm_ơn', 'các', 'bạn', 'rất', 'nhiều', '.']
# VI_INPUT ['cảm_ơn', 'rất', 'nhiều', '.']

# %%
## CALCULATE BLEU ##
bleu= torchtext.data.metrics.bleu_score(pred,ref)
print("total:",len(test_data))
print("bleu: %.2f %%"%(bleu*100))
# Out:
# total: 1269
# bleu: 19.21 %

# %%
## SHOW TRANSFORMER TRAIN LOSS ##

if LOADMODEL == False:
    te=[i for i in  LOSS]
    import matplotlib.pyplot as plt
    plt.rcParams.update({'font.size': 14})
    fig,ax = plt.subplots()
    fig.set_figwidth(10)
    fig.set_figheight(6)
    fig.patch.set_facecolor('xkcd:white')
    ax.plot([i for i in range(EPOCH)],te,label='Loss')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_title("Transformer Train Loss")
    ax.legend()
